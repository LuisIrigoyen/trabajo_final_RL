# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisIrigoyen/trabajo_final_RL/blob/main/proyecto_final_APR_V09_en_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ATENCIÓN!! Modificar ruta relativa a la práctica si es distinta (drive_root)
mount='/content/gdrive'
drive_root = mount + "/My Drive/08_MIAR/actividades/proyecto practico"

try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False

# %%
# Switch to the directory on the Google Drive that you want to use
import os
if IN_COLAB:
  print("We're running Colab")

  if IN_COLAB:
    # Mount the Google Drive at mount
    print("Colab: mounting Google drive on ", mount)

    drive.mount(mount)

    # Create drive_root if it doesn't exist
    create_drive_root = True
    if create_drive_root:
      print("\nColab: making sure ", drive_root, " exists.")
      os.makedirs(drive_root, exist_ok=True)

    # Change to the directory
    print("\nColab: Changing directory to ", drive_root)
    # %cd $drive_root
# Verify we're in the correct working directory
# %pwd
print("Archivos en el directorio: ")
print(os.listdir())
# Out:
# We're running Colab
# Colab: mounting Google drive on  /content/gdrive
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#
# Colab: making sure  /content/gdrive/My Drive/08_MIAR/actividades/proyecto practico  exists.
#
# Colab: Changing directory to  /content/gdrive/My Drive/08_MIAR/actividades/proyecto practico
# /content/gdrive/My Drive/08_MIAR/actividades/proyecto practico
# Archivos en el directorio:
# ['dqn_models', 'checkpoints', 'dqn_05_weights.h5f.data-00000-of-00001', 'dqn_05_weights.h5f.index', 'dqn_06_weights.h5f.index', 'dqn_06_weights.h5f.data-00000-of-00001', 'dqn_07_weights.h5f.index', 'checkpoint', 'dqn_07_weights.h5f.data-00000-of-00001']

# %%
if IN_COLAB:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install keras-rl2==1.0.5
  # %pip install tensorflow==2.12  #2.8
else:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install pyglet==1.5.0
  # %pip install h5py==3.1.0
  # %pip install Pillow==9.5.0
  # %pip install keras-rl3
  # %pip install Keras==2.2.4
  # %pip install tensorflow==2.10.1
  # %pip install torch==2.0.1
  # %pip install agents==1.4.0
# Out:
# Requirement already satisfied: gym==0.17.3 in /usr/local/lib/python3.11/dist-packages (0.17.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.15.3)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.23.5)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.6.0)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym==0.17.3) (1.0.0)
# Collecting git+https://github.com/Kojoley/atari-py.git
#   Cloning https://github.com/Kojoley/atari-py.git to /tmp/pip-req-build-9eea11yv
#   Running command git clone --filter=blob:none --quiet https://github.com/Kojoley/atari-py.git /tmp/pip-req-build-9eea11yv
#   Resolved https://github.com/Kojoley/atari-py.git to commit 86a1e05c0a95e9e6233c3a413521fdb34ca8a089
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from atari-py==1.2.2) (1.23.5)
# Requirement already satisfied: keras-rl2==1.0.5 in /usr/local/lib/python3.11/dist-packages (1.0.5)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (from keras-rl2==1.0.5) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.73.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.14.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.4.30)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (18.1.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (4.25.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.17.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (4.14.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow->keras-rl2==1.0.5) (0.45.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow->keras-rl2==1.0.5) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow->keras-rl2==1.0.5) (0.4.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow->keras-rl2==1.0.5) (1.15.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.2.2)
# Requirement already satisfied: tensorflow==2.12 in /usr/local/lib/python3.11/dist-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.73.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (3.14.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (0.4.30)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (18.1.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (4.25.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.17.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (4.14.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.12) (0.45.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12) (0.4.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12) (1.15.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (3.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow==2.12) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12) (3.2.2)

# %%
from __future__ import division

from PIL import Image
import numpy as np
import gym

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Convolution2D, Permute, BatchNormalization
#from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

# %%
INPUT_SHAPE = (84, 84)
WINDOW_LENGTH = 4

env_name = 'SpaceInvaders-v0'
env = gym.make(env_name)

np.random.seed(123)
env.seed(123)
nb_actions = env.action_space.n

#--- nuevo -- ejfm
height, width, channels = env.observation_space.shape
obs = env.reset()
print(height, width, channels)
print("Forma de la observación:", obs.shape)  # Debe ser (height, width, channels)
env.unwrapped.get_action_meanings()
# Out:
# 210 160 3
# Forma de la observación: (210, 160, 3)
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'RIGHTFIRE', 'LEFTFIRE']

# %%
class AtariProcessor(Processor):
    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)
        img = Image.fromarray(observation)
        img = img.resize(INPUT_SHAPE).convert('L')
        processed_observation = np.array(img)
        assert processed_observation.shape == INPUT_SHAPE
        return processed_observation.astype('uint8')

    def process_state_batch(self, batch):

        # ejfm -- modificado
        # Agrega la dimensión de canales (axis=-1) si no está presente
        if batch.ndim == 4:                         # Forma: (batch_size, window_length, h, w)
            batch = np.expand_dims(batch, axis=-1)  # Nueva forma: (batch_size, window_length, h, w, 1)
            processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return np.clip(reward, -1., 1.)

# %% [markdown]
# ## 1. EJFM Implementación de la red neuronal

# %%
# Habilita estas opciones ANTES de crear el modelo
import tensorflow as tf

physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    tf.config.optimizer.set_jit(True)  # Habilita XLA para aceleración

# Aceleración XLA (compilación optimizada)
tf.config.optimizer.set_jit(True)

# %%
def build_model(height, width, channels, actions):
    model = Sequential()

    model.add(Convolution2D(32, (8, 8), strides=4, padding='same', input_shape=(4,84,84,1)))
    model.add(Activation('relu'))

    model.add(Convolution2D(64, (4, 4), strides=2, padding='same'))
    model.add(Activation('relu'))

    model.add(Convolution2D(64, (3, 3), padding='same'))
    model.add(Activation('relu'))

    model.add(Flatten())

    model.add(Dense(512))
    model.add(Activation('relu'))

    model.add(Dense(256))
    model.add(Activation('relu'))

    # Capa de salida
    model.add(Dense(actions, activation='linear'))

    return model

model = build_model(84, 84, 1, nb_actions)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 4, 21, 21, 32)     2080
#
#  activation_5 (Activation)   (None, 4, 21, 21, 32)     0
#
#  conv2d_4 (Conv2D)           (None, 4, 11, 11, 64)     32832
#
#  activation_6 (Activation)   (None, 4, 11, 11, 64)     0
#
#  conv2d_5 (Conv2D)           (None, 4, 11, 11, 64)     36928
#
#  activation_7 (Activation)   (None, 4, 11, 11, 64)     0
#
#  flatten_1 (Flatten)         (None, 30976)             0
#
#  dense_4 (Dense)             (None, 512)               15860224
#
#  activation_8 (Activation)   (None, 512)               0
#
#  dense_5 (Dense)             (None, 256)               131328
#
#  activation_9 (Activation)   (None, 256)               0
#
#  dense_6 (Dense)             (None, 6)                 1542
#
# =================================================================
# Total params: 16,064,934
# Trainable params: 16,064,934
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 2. EJFM Implementación de la solución DQN

# %%
from rl.agents import DQNAgent
from rl.memory import SequentialMemory
from rl.policy import LinearAnnealedPolicy, EpsGreedyQPolicy
from keras.optimizers import Adam

def build_agent(model, actions):
    policy = LinearAnnealedPolicy(
        EpsGreedyQPolicy(),
        attr='eps',
        value_max=1.0,
        value_min=0.2,
        value_test=0.1,
        nb_steps=200000)

    memory = SequentialMemory(limit=200000, window_length=4)

    dqn = DQNAgent(model=model,
                   memory=memory,
                   policy=policy,
                   enable_double_dqn=True,
                   enable_dueling_network=True,
                   dueling_type='avg',
                   nb_actions=nb_actions,
                   batch_size=32,
                   target_model_update=10000,
                   processor=AtariProcessor(),
                   nb_steps_warmup=20000
                  )
    return dqn

dqn = build_agent(model, nb_actions)
dqn.compile(Adam(learning_rate=0.0005, epsilon=1e-4))

# %%
from rl.callbacks import ModelIntervalCheckpoint
import os

# Guardar el modelo cada 50,000 pasos
checkpoint_callback = ModelIntervalCheckpoint(
    filepath='checkpoints/dqn_v09_weights_{step}.h5f',
    interval=50000,
    verbose=1
)

os.makedirs("checkpoints", exist_ok=True)

# %%
from datetime import datetime

print(f"⏱ Tiempo de inicio: {datetime.now().strftime('%H:%M:%S')}")

dqn.fit(env, nb_steps=200000, visualize=False, verbose=2,callbacks=[checkpoint_callback])

print(f"⏱ Tiempo de fin: {datetime.now().strftime('%H:%M:%S')}")

# Guardando modelo
dqn.save_weights('dqn_09_weights.h5f')
# Out:
# ⏱ Tiempo de inicio: 19:20:12
# Training for 200000 steps ...
#     769/200000: episode: 1, duration: 4.588s, episode steps: 769, steps per second: 168, episode reward: 10.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.515 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    1368/200000: episode: 2, duration: 3.440s, episode steps: 599, steps per second: 174, episode reward:  1.000, mean reward:  0.002 [ 0.000,  1.000], mean action: 2.511 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    2177/200000: episode: 3, duration: 4.631s, episode steps: 809, steps per second: 175, episode reward: 13.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.407 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    2577/200000: episode: 4, duration: 2.407s, episode steps: 400, steps per second: 166, episode reward:  4.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.560 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    3313/200000: episode: 5, duration: 4.212s, episode steps: 736, steps per second: 175, episode reward: 10.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.485 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    3813/200000: episode: 6, duration: 2.840s, episode steps: 500, steps per second: 176, episode reward:  7.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.414 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    4392/200000: episode: 7, duration: 3.290s, episode steps: 579, steps per second: 176, episode reward:  6.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.535 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    4928/200000: episode: 8, duration: 3.124s, episode steps: 536, steps per second: 172, episode reward:  7.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.437 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    5595/200000: episode: 9, duration: 3.809s, episode steps: 667, steps per second: 175, episode reward:  7.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.456 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    6349/200000: episode: 10, duration: 4.274s, episode steps: 754, steps per second: 176, episode reward:  6.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 2.448 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    6890/200000: episode: 11, duration: 3.084s, episode steps: 541, steps per second: 175, episode reward:  9.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.562 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    7855/200000: episode: 12, duration: 5.538s, episode steps: 965, steps per second: 174, episode reward: 24.000, mean reward:  0.025 [ 0.000,  1.000], mean action: 2.545 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    8475/200000: episode: 13, duration: 3.528s, episode steps: 620, steps per second: 176, episode reward:  8.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.456 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    9078/200000: episode: 14, duration: 3.441s, episode steps: 603, steps per second: 175, episode reward:  8.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.537 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    9747/200000: episode: 15, duration: 3.860s, episode steps: 669, steps per second: 173, episode reward:  9.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.486 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   10286/200000: episode: 16, duration: 3.114s, episode steps: 539, steps per second: 173, episode reward:  5.000, mean reward:  0.009 [ 0.000,  1.000], mean action: 2.573 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   10940/200000: episode: 17, duration: 3.675s, episode steps: 654, steps per second: 178, episode reward:  9.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.583 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   11569/200000: episode: 18, duration: 3.666s, episode steps: 629, steps per second: 172, episode reward:  5.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 2.521 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   11953/200000: episode: 19, duration: 2.161s, episode steps: 384, steps per second: 178, episode reward:  4.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.615 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   12690/200000: episode: 20, duration: 4.147s, episode steps: 737, steps per second: 178, episode reward: 11.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.430 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   13180/200000: episode: 21, duration: 2.763s, episode steps: 490, steps per second: 177, episode reward:  6.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.531 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   13831/200000: episode: 22, duration: 3.782s, episode steps: 651, steps per second: 172, episode reward:  8.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.449 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   14399/200000: episode: 23, duration: 3.213s, episode steps: 568, steps per second: 177, episode reward:  8.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.592 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   15839/200000: episode: 24, duration: 8.128s, episode steps: 1440, steps per second: 177, episode reward: 16.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.441 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   16384/200000: episode: 25, duration: 3.128s, episode steps: 545, steps per second: 174, episode reward:  7.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.244 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   16794/200000: episode: 26, duration: 2.318s, episode steps: 410, steps per second: 177, episode reward:  6.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.517 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   17577/200000: episode: 27, duration: 4.407s, episode steps: 783, steps per second: 178, episode reward: 10.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.501 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   18288/200000: episode: 28, duration: 4.168s, episode steps: 711, steps per second: 171, episode reward:  7.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.475 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   19145/200000: episode: 29, duration: 4.845s, episode steps: 857, steps per second: 177, episode reward: 12.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.379 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   19843/200000: episode: 30, duration: 3.932s, episode steps: 698, steps per second: 178, episode reward:  7.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.437 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
# /usr/local/lib/python3.11/dist-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
#   20690/200000: episode: 31, duration: 109.857s, episode steps: 847, steps per second:   8, episode reward: 11.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.733 [0.000, 5.000],  loss: 0.007072, mean_q: 0.012828, mean_eps: 0.918620
#   21337/200000: episode: 32, duration: 100.992s, episode steps: 647, steps per second:   6, episode reward:  8.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.587 [0.000, 5.000],  loss: 0.006577, mean_q: 0.008700, mean_eps: 0.915948
#   21973/200000: episode: 33, duration: 99.092s, episode steps: 636, steps per second:   6, episode reward:  8.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.542 [0.000, 5.000],  loss: 0.006423, mean_q: 0.009607, mean_eps: 0.913382
#   22588/200000: episode: 34, duration: 95.952s, episode steps: 615, steps per second:   6, episode reward:  8.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.592 [0.000, 5.000],  loss: 0.005887, mean_q: 0.007801, mean_eps: 0.910880
#   23089/200000: episode: 35, duration: 78.279s, episode steps: 501, steps per second:   6, episode reward:  5.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.457 [0.000, 5.000],  loss: 0.007170, mean_q: 0.011037, mean_eps: 0.908648
#   23981/200000: episode: 36, duration: 139.298s, episode steps: 892, steps per second:   6, episode reward: 17.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.541 [0.000, 5.000],  loss: 0.006661, mean_q: 0.010971, mean_eps: 0.905862
#   24921/200000: episode: 37, duration: 146.763s, episode steps: 940, steps per second:   6, episode reward: 15.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.481 [0.000, 5.000],  loss: 0.006481, mean_q: 0.011418, mean_eps: 0.902198
#   25322/200000: episode: 38, duration: 62.789s, episode steps: 401, steps per second:   6, episode reward:  6.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.708 [0.000, 5.000],  loss: 0.006732, mean_q: 0.006171, mean_eps: 0.899516
#   25728/200000: episode: 39, duration: 63.430s, episode steps: 406, steps per second:   6, episode reward:  7.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.421 [0.000, 5.000],  loss: 0.006162, mean_q: 0.010906, mean_eps: 0.897902
#   26254/200000: episode: 40, duration: 82.177s, episode steps: 526, steps per second:   6, episode reward:  6.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.445 [0.000, 5.000],  loss: 0.006590, mean_q: 0.010259, mean_eps: 0.896038
#   27041/200000: episode: 41, duration: 122.861s, episode steps: 787, steps per second:   6, episode reward: 13.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.573 [0.000, 5.000],  loss: 0.007229, mean_q: 0.013127, mean_eps: 0.893412
#   27797/200000: episode: 42, duration: 118.396s, episode steps: 756, steps per second:   6, episode reward:  9.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.407 [0.000, 5.000],  loss: 0.007004, mean_q: 0.009386, mean_eps: 0.890326
#   28286/200000: episode: 43, duration: 77.047s, episode steps: 489, steps per second:   6, episode reward:  6.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.550 [0.000, 5.000],  loss: 0.006951, mean_q: 0.010829, mean_eps: 0.887836
#   29532/200000: episode: 44, duration: 194.384s, episode steps: 1246, steps per second:   6, episode reward: 12.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.506 [0.000, 5.000],  loss: 0.006833, mean_q: 0.010338, mean_eps: 0.884366
#   30425/200000: episode: 45, duration: 140.235s, episode steps: 893, steps per second:   6, episode reward: 13.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.499 [0.000, 5.000],  loss: 0.006255, mean_q: 0.014155, mean_eps: 0.880088
#   31214/200000: episode: 46, duration: 122.929s, episode steps: 789, steps per second:   6, episode reward: 13.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.610 [0.000, 5.000],  loss: 0.006638, mean_q: 0.025177, mean_eps: 0.876724
#   31836/200000: episode: 47, duration: 97.111s, episode steps: 622, steps per second:   6, episode reward:  5.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 2.690 [0.000, 5.000],  loss: 0.006489, mean_q: 0.026910, mean_eps: 0.873902
#   32358/200000: episode: 48, duration: 82.265s, episode steps: 522, steps per second:   6, episode reward:  5.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.515 [0.000, 5.000],  loss: 0.005933, mean_q: 0.022946, mean_eps: 0.871614
#   33352/200000: episode: 49, duration: 156.825s, episode steps: 994, steps per second:   6, episode reward: 14.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.502 [0.000, 5.000],  loss: 0.006694, mean_q: 0.024111, mean_eps: 0.868582
#   33886/200000: episode: 50, duration: 83.496s, episode steps: 534, steps per second:   6, episode reward:  7.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.436 [0.000, 5.000],  loss: 0.006551, mean_q: 0.024353, mean_eps: 0.865526
#   34269/200000: episode: 51, duration: 59.902s, episode steps: 383, steps per second:   6, episode reward:  4.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.493 [0.000, 5.000],  loss: 0.006379, mean_q: 0.026536, mean_eps: 0.863692
#   34819/200000: episode: 52, duration: 86.392s, episode steps: 550, steps per second:   6, episode reward:  4.000, mean reward:  0.007 [ 0.000,  1.000], mean action: 2.531 [0.000, 5.000],  loss: 0.006588, mean_q: 0.023146, mean_eps: 0.861826
#   35937/200000: episode: 53, duration: 174.817s, episode steps: 1118, steps per second:   6, episode reward: 13.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.482 [0.000, 5.000],  loss: 0.006226, mean_q: 0.025549, mean_eps: 0.858490
#   36530/200000: episode: 54, duration: 92.498s, episode steps: 593, steps per second:   6, episode reward:  8.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.499 [0.000, 5.000],  loss: 0.005695, mean_q: 0.023183, mean_eps: 0.855068
#   37259/200000: episode: 55, duration: 113.859s, episode steps: 729, steps per second:   6, episode reward:  7.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.436 [0.000, 5.000],  loss: 0.006202, mean_q: 0.025159, mean_eps: 0.852424
#   37908/200000: episode: 56, duration: 101.282s, episode steps: 649, steps per second:   6, episode reward:  9.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.716 [0.000, 5.000],  loss: 0.006394, mean_q: 0.026000, mean_eps: 0.849668
#   39075/200000: episode: 57, duration: 183.203s, episode steps: 1167, steps per second:   6, episode reward: 14.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.428 [0.000, 5.000],  loss: 0.006196, mean_q: 0.025528, mean_eps: 0.846036
#   39732/200000: episode: 58, duration: 103.735s, episode steps: 657, steps per second:   6, episode reward: 12.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.495 [0.000, 5.000],  loss: 0.006087, mean_q: 0.022834, mean_eps: 0.842388
#   40236/200000: episode: 59, duration: 79.649s, episode steps: 504, steps per second:   6, episode reward:  5.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.671 [0.000, 5.000],  loss: 0.006640, mean_q: 0.037288, mean_eps: 0.840066
#   40946/200000: episode: 60, duration: 112.485s, episode steps: 710, steps per second:   6, episode reward:  8.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.634 [0.000, 5.000],  loss: 0.005838, mean_q: 0.045799, mean_eps: 0.837638
#   41357/200000: episode: 61, duration: 65.143s, episode steps: 411, steps per second:   6, episode reward:  6.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.657 [0.000, 5.000],  loss: 0.005893, mean_q: 0.042447, mean_eps: 0.835396
#   41817/200000: episode: 62, duration: 72.368s, episode steps: 460, steps per second:   6, episode reward:  6.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.502 [0.000, 5.000],  loss: 0.005636, mean_q: 0.046251, mean_eps: 0.833654
#   42737/200000: episode: 63, duration: 145.002s, episode steps: 920, steps per second:   6, episode reward: 11.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.586 [0.000, 5.000],  loss: 0.006738, mean_q: 0.048370, mean_eps: 0.830894
#   43210/200000: episode: 64, duration: 74.456s, episode steps: 473, steps per second:   6, episode reward:  4.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 2.476 [0.000, 5.000],  loss: 0.006855, mean_q: 0.047627, mean_eps: 0.828108
#   44009/200000: episode: 65, duration: 125.516s, episode steps: 799, steps per second:   6, episode reward: 14.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.558 [0.000, 5.000],  loss: 0.006115, mean_q: 0.045004, mean_eps: 0.825564
#   44759/200000: episode: 66, duration: 117.546s, episode steps: 750, steps per second:   6, episode reward: 12.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.431 [0.000, 5.000],  loss: 0.006276, mean_q: 0.047466, mean_eps: 0.822466
#   45517/200000: episode: 67, duration: 118.772s, episode steps: 758, steps per second:   6, episode reward: 11.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.487 [0.000, 5.000],  loss: 0.005705, mean_q: 0.045420, mean_eps: 0.819450
#   46193/200000: episode: 68, duration: 105.877s, episode steps: 676, steps per second:   6, episode reward:  8.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.478 [0.000, 5.000],  loss: 0.006715, mean_q: 0.050009, mean_eps: 0.816582
#   46839/200000: episode: 69, duration: 101.205s, episode steps: 646, steps per second:   6, episode reward: 11.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.223 [0.000, 5.000],  loss: 0.005940, mean_q: 0.046828, mean_eps: 0.813938
#   47424/200000: episode: 70, duration: 92.236s, episode steps: 585, steps per second:   6, episode reward:  7.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.593 [0.000, 5.000],  loss: 0.006346, mean_q: 0.048779, mean_eps: 0.811476
#   48241/200000: episode: 71, duration: 128.091s, episode steps: 817, steps per second:   6, episode reward: 12.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.284 [0.000, 5.000],  loss: 0.005695, mean_q: 0.046986, mean_eps: 0.808672
#   48774/200000: episode: 72, duration: 84.000s, episode steps: 533, steps per second:   6, episode reward:  4.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 2.313 [0.000, 5.000],  loss: 0.006211, mean_q: 0.047025, mean_eps: 0.805972
#   49540/200000: episode: 73, duration: 120.788s, episode steps: 766, steps per second:   6, episode reward: 12.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.452 [0.000, 5.000],  loss: 0.006348, mean_q: 0.049224, mean_eps: 0.803374
# Step 50000: saving model to checkpoints/dqn_v09_weights_50000.h5f
#   50189/200000: episode: 74, duration: 102.234s, episode steps: 649, steps per second:   6, episode reward: 10.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.455 [0.000, 5.000],  loss: 0.006182, mean_q: 0.056144, mean_eps: 0.800544
#   50669/200000: episode: 75, duration: 75.185s, episode steps: 480, steps per second:   6, episode reward:  6.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.592 [0.000, 5.000],  loss: 0.007387, mean_q: 0.082324, mean_eps: 0.798286
#   51941/200000: episode: 76, duration: 200.527s, episode steps: 1272, steps per second:   6, episode reward: 16.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.503 [0.000, 5.000],  loss: 0.005883, mean_q: 0.074774, mean_eps: 0.794782
#   52815/200000: episode: 77, duration: 136.990s, episode steps: 874, steps per second:   6, episode reward: 13.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.590 [0.000, 5.000],  loss: 0.005310, mean_q: 0.070773, mean_eps: 0.790490
#   53368/200000: episode: 78, duration: 87.039s, episode steps: 553, steps per second:   6, episode reward:  9.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.472 [0.000, 5.000],  loss: 0.005712, mean_q: 0.073378, mean_eps: 0.787636
#   54394/200000: episode: 79, duration: 160.332s, episode steps: 1026, steps per second:   6, episode reward: 20.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.557 [0.000, 5.000],  loss: 0.005958, mean_q: 0.074634, mean_eps: 0.784478
#   54929/200000: episode: 80, duration: 83.764s, episode steps: 535, steps per second:   6, episode reward:  7.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.510 [0.000, 5.000],  loss: 0.005617, mean_q: 0.073191, mean_eps: 0.781356
#   55514/200000: episode: 81, duration: 91.532s, episode steps: 585, steps per second:   6, episode reward:  6.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.472 [0.000, 5.000],  loss: 0.006260, mean_q: 0.073871, mean_eps: 0.779116
#   56319/200000: episode: 82, duration: 125.808s, episode steps: 805, steps per second:   6, episode reward:  9.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.406 [0.000, 5.000],  loss: 0.006391, mean_q: 0.077850, mean_eps: 0.776336
#   57265/200000: episode: 83, duration: 147.741s, episode steps: 946, steps per second:   6, episode reward: 19.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.667 [0.000, 5.000],  loss: 0.005479, mean_q: 0.073712, mean_eps: 0.772834
#   58071/200000: episode: 84, duration: 126.036s, episode steps: 806, steps per second:   6, episode reward: 12.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.524 [0.000, 5.000],  loss: 0.006294, mean_q: 0.075132, mean_eps: 0.769330
#   58602/200000: episode: 85, duration: 83.077s, episode steps: 531, steps per second:   6, episode reward:  6.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.503 [0.000, 5.000],  loss: 0.006092, mean_q: 0.073652, mean_eps: 0.766656
#   59027/200000: episode: 86, duration: 66.739s, episode steps: 425, steps per second:   6, episode reward:  7.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.522 [0.000, 5.000],  loss: 0.005780, mean_q: 0.073213, mean_eps: 0.764744
#   59905/200000: episode: 87, duration: 138.437s, episode steps: 878, steps per second:   6, episode reward: 16.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.441 [0.000, 5.000],  loss: 0.005806, mean_q: 0.076941, mean_eps: 0.762138
#   60464/200000: episode: 88, duration: 88.079s, episode steps: 559, steps per second:   6, episode reward:  8.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.533 [0.000, 5.000],  loss: 0.007062, mean_q: 0.102463, mean_eps: 0.759264
#   61317/200000: episode: 89, duration: 133.859s, episode steps: 853, steps per second:   6, episode reward: 12.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.608 [0.000, 5.000],  loss: 0.005822, mean_q: 0.098521, mean_eps: 0.756440
#   61732/200000: episode: 90, duration: 65.155s, episode steps: 415, steps per second:   6, episode reward:  6.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.501 [0.000, 5.000],  loss: 0.006753, mean_q: 0.099100, mean_eps: 0.753904
#   62610/200000: episode: 91, duration: 137.629s, episode steps: 878, steps per second:   6, episode reward: 17.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.459 [0.000, 5.000],  loss: 0.006445, mean_q: 0.102850, mean_eps: 0.751318
#   63858/200000: episode: 92, duration: 195.725s, episode steps: 1248, steps per second:   6, episode reward: 19.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.540 [0.000, 5.000],  loss: 0.006061, mean_q: 0.099247, mean_eps: 0.747066
#   64381/200000: episode: 93, duration: 82.099s, episode steps: 523, steps per second:   6, episode reward:  6.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.627 [0.000, 5.000],  loss: 0.005515, mean_q: 0.104828, mean_eps: 0.743524
#   64780/200000: episode: 94, duration: 63.235s, episode steps: 399, steps per second:   6, episode reward:  5.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.278 [0.000, 5.000],  loss: 0.006283, mean_q: 0.104151, mean_eps: 0.741680
#   65416/200000: episode: 95, duration: 100.132s, episode steps: 636, steps per second:   6, episode reward:  7.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.517 [0.000, 5.000],  loss: 0.005758, mean_q: 0.099592, mean_eps: 0.739610
#   65961/200000: episode: 96, duration: 86.117s, episode steps: 545, steps per second:   6, episode reward:  6.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.580 [0.000, 5.000],  loss: 0.005622, mean_q: 0.098120, mean_eps: 0.737248
#   66889/200000: episode: 97, duration: 146.473s, episode steps: 928, steps per second:   6, episode reward: 12.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.515 [0.000, 5.000],  loss: 0.005818, mean_q: 0.100026, mean_eps: 0.734302
#   67441/200000: episode: 98, duration: 86.755s, episode steps: 552, steps per second:   6, episode reward:  8.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.603 [0.000, 5.000],  loss: 0.005753, mean_q: 0.102600, mean_eps: 0.731342
#   67897/200000: episode: 99, duration: 71.674s, episode steps: 456, steps per second:   6, episode reward:  8.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.452 [0.000, 5.000],  loss: 0.005828, mean_q: 0.102995, mean_eps: 0.729326
#   68823/200000: episode: 100, duration: 145.819s, episode steps: 926, steps per second:   6, episode reward:  9.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.544 [0.000, 5.000],  loss: 0.006285, mean_q: 0.101852, mean_eps: 0.726562
#   69446/200000: episode: 101, duration: 97.802s, episode steps: 623, steps per second:   6, episode reward: 10.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.642 [0.000, 5.000],  loss: 0.005129, mean_q: 0.099820, mean_eps: 0.723464
#   70302/200000: episode: 102, duration: 134.415s, episode steps: 856, steps per second:   6, episode reward: 13.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.383 [0.000, 5.000],  loss: 0.006784, mean_q: 0.118822, mean_eps: 0.720506
#   70925/200000: episode: 103, duration: 97.943s, episode steps: 623, steps per second:   6, episode reward:  7.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.557 [0.000, 5.000],  loss: 0.007003, mean_q: 0.136779, mean_eps: 0.717548
#   72116/200000: episode: 104, duration: 186.616s, episode steps: 1191, steps per second:   6, episode reward: 25.000, mean reward:  0.021 [ 0.000,  1.000], mean action: 2.552 [0.000, 5.000],  loss: 0.006544, mean_q: 0.133669, mean_eps: 0.713920
#   72830/200000: episode: 105, duration: 112.088s, episode steps: 714, steps per second:   6, episode reward:  8.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.529 [0.000, 5.000],  loss: 0.007143, mean_q: 0.134858, mean_eps: 0.710110
#   73317/200000: episode: 106, duration: 76.374s, episode steps: 487, steps per second:   6, episode reward:  2.000, mean reward:  0.004 [ 0.000,  1.000], mean action: 2.585 [0.000, 5.000],  loss: 0.005575, mean_q: 0.131454, mean_eps: 0.707708
#   73664/200000: episode: 107, duration: 54.538s, episode steps: 347, steps per second:   6, episode reward:  4.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.651 [0.000, 5.000],  loss: 0.006471, mean_q: 0.138026, mean_eps: 0.706040
#   74603/200000: episode: 108, duration: 147.087s, episode steps: 939, steps per second:   6, episode reward: 10.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.431 [0.000, 5.000],  loss: 0.006147, mean_q: 0.135248, mean_eps: 0.703468
#   75768/200000: episode: 109, duration: 183.347s, episode steps: 1165, steps per second:   6, episode reward: 17.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.600 [0.000, 5.000],  loss: 0.006441, mean_q: 0.134749, mean_eps: 0.699260
#   76662/200000: episode: 110, duration: 141.061s, episode steps: 894, steps per second:   6, episode reward: 12.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.497 [0.000, 5.000],  loss: 0.006033, mean_q: 0.133809, mean_eps: 0.695142
#   77195/200000: episode: 111, duration: 84.451s, episode steps: 533, steps per second:   6, episode reward:  9.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.465 [0.000, 5.000],  loss: 0.005363, mean_q: 0.131542, mean_eps: 0.692288
#   77893/200000: episode: 112, duration: 109.421s, episode steps: 698, steps per second:   6, episode reward:  6.000, mean reward:  0.009 [ 0.000,  1.000], mean action: 2.390 [0.000, 5.000],  loss: 0.006194, mean_q: 0.135093, mean_eps: 0.689826
#   78274/200000: episode: 113, duration: 59.824s, episode steps: 381, steps per second:   6, episode reward:  7.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.583 [0.000, 5.000],  loss: 0.006267, mean_q: 0.134163, mean_eps: 0.687668
#   79284/200000: episode: 114, duration: 158.578s, episode steps: 1010, steps per second:   6, episode reward: 14.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.547 [0.000, 5.000],  loss: 0.005681, mean_q: 0.133819, mean_eps: 0.684886
#   80101/200000: episode: 115, duration: 128.483s, episode steps: 817, steps per second:   6, episode reward: 11.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.405 [0.000, 5.000],  loss: 0.005932, mean_q: 0.140418, mean_eps: 0.681232
#   80762/200000: episode: 116, duration: 104.751s, episode steps: 661, steps per second:   6, episode reward: 11.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.658 [0.000, 5.000],  loss: 0.007766, mean_q: 0.178228, mean_eps: 0.678276
#   81520/200000: episode: 117, duration: 119.574s, episode steps: 758, steps per second:   6, episode reward: 12.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.515 [0.000, 5.000],  loss: 0.008054, mean_q: 0.177177, mean_eps: 0.675438
#   82019/200000: episode: 118, duration: 78.752s, episode steps: 499, steps per second:   6, episode reward:  6.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.549 [0.000, 5.000],  loss: 0.007934, mean_q: 0.178474, mean_eps: 0.672924
#   82584/200000: episode: 119, duration: 89.565s, episode steps: 565, steps per second:   6, episode reward:  8.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.796 [0.000, 5.000],  loss: 0.008169, mean_q: 0.174377, mean_eps: 0.670796
#   83159/200000: episode: 120, duration: 90.532s, episode steps: 575, steps per second:   6, episode reward:  3.000, mean reward:  0.005 [ 0.000,  1.000], mean action: 2.457 [0.000, 5.000],  loss: 0.006926, mean_q: 0.172723, mean_eps: 0.668516
#   83778/200000: episode: 121, duration: 97.439s, episode steps: 619, steps per second:   6, episode reward:  7.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.696 [0.000, 5.000],  loss: 0.006511, mean_q: 0.171527, mean_eps: 0.666128
#   84376/200000: episode: 122, duration: 94.685s, episode steps: 598, steps per second:   6, episode reward: 11.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.535 [0.000, 5.000],  loss: 0.006536, mean_q: 0.172961, mean_eps: 0.663694
#   85206/200000: episode: 123, duration: 131.280s, episode steps: 830, steps per second:   6, episode reward: 11.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.399 [0.000, 5.000],  loss: 0.006510, mean_q: 0.169651, mean_eps: 0.660838
#   85697/200000: episode: 124, duration: 77.323s, episode steps: 491, steps per second:   6, episode reward:  8.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.527 [0.000, 5.000],  loss: 0.006236, mean_q: 0.169579, mean_eps: 0.658196
#   86077/200000: episode: 125, duration: 59.985s, episode steps: 380, steps per second:   6, episode reward:  5.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.161 [0.000, 5.000],  loss: 0.005986, mean_q: 0.166806, mean_eps: 0.656454
#   86844/200000: episode: 126, duration: 121.096s, episode steps: 767, steps per second:   6, episode reward: 10.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.652 [0.000, 5.000],  loss: 0.006436, mean_q: 0.174319, mean_eps: 0.654160
#   87264/200000: episode: 127, duration: 66.163s, episode steps: 420, steps per second:   6, episode reward:  5.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.512 [0.000, 5.000],  loss: 0.005567, mean_q: 0.168623, mean_eps: 0.651786
#   87653/200000: episode: 128, duration: 61.399s, episode steps: 389, steps per second:   6, episode reward:  5.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.720 [0.000, 5.000],  loss: 0.006329, mean_q: 0.176435, mean_eps: 0.650168
#   88336/200000: episode: 129, duration: 107.784s, episode steps: 683, steps per second:   6, episode reward:  8.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.261 [0.000, 5.000],  loss: 0.005443, mean_q: 0.169079, mean_eps: 0.648024
#   88842/200000: episode: 130, duration: 79.904s, episode steps: 506, steps per second:   6, episode reward:  7.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.636 [0.000, 5.000],  loss: 0.005461, mean_q: 0.169577, mean_eps: 0.645646
#   89485/200000: episode: 131, duration: 101.645s, episode steps: 643, steps per second:   6, episode reward:  9.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.367 [0.000, 5.000],  loss: 0.005730, mean_q: 0.173568, mean_eps: 0.643348
#   90417/200000: episode: 132, duration: 147.064s, episode steps: 932, steps per second:   6, episode reward: 10.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.665 [0.000, 5.000],  loss: 0.006623, mean_q: 0.186225, mean_eps: 0.640198
#   90948/200000: episode: 133, duration: 83.651s, episode steps: 531, steps per second:   6, episode reward:  6.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.350 [0.000, 5.000],  loss: 0.007442, mean_q: 0.197931, mean_eps: 0.637272
#   91555/200000: episode: 134, duration: 95.540s, episode steps: 607, steps per second:   6, episode reward:  9.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.300 [0.000, 5.000],  loss: 0.007537, mean_q: 0.197415, mean_eps: 0.634996
#   92259/200000: episode: 135, duration: 111.061s, episode steps: 704, steps per second:   6, episode reward:  9.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.473 [0.000, 5.000],  loss: 0.006589, mean_q: 0.192411, mean_eps: 0.632374
#   92681/200000: episode: 136, duration: 66.449s, episode steps: 422, steps per second:   6, episode reward:  5.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.616 [0.000, 5.000],  loss: 0.006050, mean_q: 0.190833, mean_eps: 0.630122
#   93061/200000: episode: 137, duration: 59.848s, episode steps: 380, steps per second:   6, episode reward:  5.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.497 [0.000, 5.000],  loss: 0.007145, mean_q: 0.197278, mean_eps: 0.628518
#   93477/200000: episode: 138, duration: 65.969s, episode steps: 416, steps per second:   6, episode reward:  5.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.832 [0.000, 5.000],  loss: 0.005962, mean_q: 0.190840, mean_eps: 0.626926
#   94099/200000: episode: 139, duration: 98.004s, episode steps: 622, steps per second:   6, episode reward:  7.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.730 [0.000, 5.000],  loss: 0.006080, mean_q: 0.194208, mean_eps: 0.624850
#   95585/200000: episode: 140, duration: 234.033s, episode steps: 1486, steps per second:   6, episode reward: 17.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.557 [0.000, 5.000],  loss: 0.006261, mean_q: 0.194374, mean_eps: 0.620634
#   95974/200000: episode: 141, duration: 61.300s, episode steps: 389, steps per second:   6, episode reward:  4.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.501 [0.000, 5.000],  loss: 0.006225, mean_q: 0.196239, mean_eps: 0.616884
#   96515/200000: episode: 142, duration: 85.333s, episode steps: 541, steps per second:   6, episode reward:  6.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.501 [0.000, 5.000],  loss: 0.006198, mean_q: 0.193853, mean_eps: 0.615024
#   97143/200000: episode: 143, duration: 99.619s, episode steps: 628, steps per second:   6, episode reward:  7.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.425 [0.000, 5.000],  loss: 0.005782, mean_q: 0.193913, mean_eps: 0.612686
#   97975/200000: episode: 144, duration: 131.211s, episode steps: 832, steps per second:   6, episode reward: 13.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.385 [0.000, 5.000],  loss: 0.004918, mean_q: 0.187315, mean_eps: 0.609766
#   98723/200000: episode: 145, duration: 118.023s, episode steps: 748, steps per second:   6, episode reward: 11.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.616 [0.000, 5.000],  loss: 0.005682, mean_q: 0.193795, mean_eps: 0.606606
#   99334/200000: episode: 146, duration: 96.644s, episode steps: 611, steps per second:   6, episode reward:  7.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.522 [0.000, 5.000],  loss: 0.005800, mean_q: 0.189302, mean_eps: 0.603888
# Step 100000: saving model to checkpoints/dqn_v09_weights_100000.h5f
#  100012/200000: episode: 147, duration: 107.141s, episode steps: 678, steps per second:   6, episode reward: 10.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.558 [0.000, 5.000],  loss: 0.005466, mean_q: 0.193691, mean_eps: 0.601310
#  100646/200000: episode: 148, duration: 100.673s, episode steps: 634, steps per second:   6, episode reward: 11.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.675 [0.000, 5.000],  loss: 0.009165, mean_q: 0.229054, mean_eps: 0.598686
#  101791/200000: episode: 149, duration: 180.759s, episode steps: 1145, steps per second:   6, episode reward: 14.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.580 [0.000, 5.000],  loss: 0.008495, mean_q: 0.223135, mean_eps: 0.595128
#  102727/200000: episode: 150, duration: 147.930s, episode steps: 936, steps per second:   6, episode reward: 13.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.516 [0.000, 5.000],  loss: 0.007159, mean_q: 0.222360, mean_eps: 0.590966
#  103519/200000: episode: 151, duration: 125.182s, episode steps: 792, steps per second:   6, episode reward: 11.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.508 [0.000, 5.000],  loss: 0.007210, mean_q: 0.222443, mean_eps: 0.587510
#  104384/200000: episode: 152, duration: 136.835s, episode steps: 865, steps per second:   6, episode reward: 10.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.681 [0.000, 5.000],  loss: 0.006812, mean_q: 0.219995, mean_eps: 0.584196
#  105682/200000: episode: 153, duration: 205.616s, episode steps: 1298, steps per second:   6, episode reward: 15.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.624 [0.000, 5.000],  loss: 0.007114, mean_q: 0.223334, mean_eps: 0.579870
#  106200/200000: episode: 154, duration: 82.350s, episode steps: 518, steps per second:   6, episode reward:  7.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.772 [0.000, 5.000],  loss: 0.006227, mean_q: 0.213487, mean_eps: 0.576238
#  106795/200000: episode: 155, duration: 94.385s, episode steps: 595, steps per second:   6, episode reward:  7.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.444 [0.000, 5.000],  loss: 0.006443, mean_q: 0.221732, mean_eps: 0.574012
#  107421/200000: episode: 156, duration: 99.362s, episode steps: 626, steps per second:   6, episode reward:  8.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.586 [0.000, 5.000],  loss: 0.006137, mean_q: 0.212877, mean_eps: 0.571570
#  107939/200000: episode: 157, duration: 82.388s, episode steps: 518, steps per second:   6, episode reward:  6.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.595 [0.000, 5.000],  loss: 0.007284, mean_q: 0.219048, mean_eps: 0.569282
#  108549/200000: episode: 158, duration: 96.686s, episode steps: 610, steps per second:   6, episode reward:  8.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.552 [0.000, 5.000],  loss: 0.006238, mean_q: 0.216434, mean_eps: 0.567026
#  109072/200000: episode: 159, duration: 83.180s, episode steps: 523, steps per second:   6, episode reward:  6.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.503 [0.000, 5.000],  loss: 0.005331, mean_q: 0.213460, mean_eps: 0.564760
#  110284/200000: episode: 160, duration: 192.662s, episode steps: 1212, steps per second:   6, episode reward: 27.000, mean reward:  0.022 [ 0.000,  1.000], mean action: 2.536 [0.000, 5.000],  loss: 0.006618, mean_q: 0.230489, mean_eps: 0.561290
#  111118/200000: episode: 161, duration: 132.079s, episode steps: 834, steps per second:   6, episode reward: 15.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.568 [0.000, 5.000],  loss: 0.008954, mean_q: 0.261140, mean_eps: 0.557198
#  111527/200000: episode: 162, duration: 64.933s, episode steps: 409, steps per second:   6, episode reward:  6.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.653 [0.000, 5.000],  loss: 0.008119, mean_q: 0.252198, mean_eps: 0.554712
#  112042/200000: episode: 163, duration: 81.557s, episode steps: 515, steps per second:   6, episode reward: 10.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.513 [0.000, 5.000],  loss: 0.008523, mean_q: 0.266939, mean_eps: 0.552864
#  112668/200000: episode: 164, duration: 98.986s, episode steps: 626, steps per second:   6, episode reward:  9.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.521 [0.000, 5.000],  loss: 0.007718, mean_q: 0.260752, mean_eps: 0.550582
#  113312/200000: episode: 165, duration: 101.812s, episode steps: 644, steps per second:   6, episode reward: 12.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.534 [0.000, 5.000],  loss: 0.007520, mean_q: 0.259208, mean_eps: 0.548042
#  113942/200000: episode: 166, duration: 99.690s, episode steps: 630, steps per second:   6, episode reward:  6.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.343 [0.000, 5.000],  loss: 0.006917, mean_q: 0.250887, mean_eps: 0.545494
#  114398/200000: episode: 167, duration: 72.273s, episode steps: 456, steps per second:   6, episode reward:  4.000, mean reward:  0.009 [ 0.000,  1.000], mean action: 2.454 [0.000, 5.000],  loss: 0.006959, mean_q: 0.256432, mean_eps: 0.543322
#  114820/200000: episode: 168, duration: 66.709s, episode steps: 422, steps per second:   6, episode reward:  7.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.604 [0.000, 5.000],  loss: 0.006812, mean_q: 0.251833, mean_eps: 0.541566
#  115368/200000: episode: 169, duration: 86.717s, episode steps: 548, steps per second:   6, episode reward:  7.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.768 [0.000, 5.000],  loss: 0.006506, mean_q: 0.251597, mean_eps: 0.539626
#  115990/200000: episode: 170, duration: 98.445s, episode steps: 622, steps per second:   6, episode reward:  8.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.703 [0.000, 5.000],  loss: 0.006574, mean_q: 0.254320, mean_eps: 0.537286
#  116506/200000: episode: 171, duration: 81.776s, episode steps: 516, steps per second:   6, episode reward:  9.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.380 [0.000, 5.000],  loss: 0.006728, mean_q: 0.257384, mean_eps: 0.535010
#  116902/200000: episode: 172, duration: 63.045s, episode steps: 396, steps per second:   6, episode reward:  7.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.611 [0.000, 5.000],  loss: 0.006046, mean_q: 0.257325, mean_eps: 0.533186
#  117531/200000: episode: 173, duration: 99.932s, episode steps: 629, steps per second:   6, episode reward: 12.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.560 [0.000, 5.000],  loss: 0.005950, mean_q: 0.251823, mean_eps: 0.531136
#  118072/200000: episode: 174, duration: 86.093s, episode steps: 541, steps per second:   6, episode reward:  7.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.680 [0.000, 5.000],  loss: 0.006004, mean_q: 0.251090, mean_eps: 0.528796
#  118655/200000: episode: 175, duration: 92.592s, episode steps: 583, steps per second:   6, episode reward:  4.000, mean reward:  0.007 [ 0.000,  1.000], mean action: 2.492 [0.000, 5.000],  loss: 0.005836, mean_q: 0.249225, mean_eps: 0.526548
#  119041/200000: episode: 176, duration: 61.240s, episode steps: 386, steps per second:   6, episode reward:  5.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.337 [0.000, 5.000],  loss: 0.005751, mean_q: 0.259920, mean_eps: 0.524610
#  119790/200000: episode: 177, duration: 118.666s, episode steps: 749, steps per second:   6, episode reward:  9.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.514 [0.000, 5.000],  loss: 0.006143, mean_q: 0.255975, mean_eps: 0.522340
#  120397/200000: episode: 178, duration: 96.475s, episode steps: 607, steps per second:   6, episode reward:  9.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.582 [0.000, 5.000],  loss: 0.007133, mean_q: 0.268297, mean_eps: 0.519628
#  121078/200000: episode: 179, duration: 108.895s, episode steps: 681, steps per second:   6, episode reward: 12.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.731 [0.000, 5.000],  loss: 0.008413, mean_q: 0.275693, mean_eps: 0.517052
#  121767/200000: episode: 180, duration: 109.592s, episode steps: 689, steps per second:   6, episode reward: 12.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.826 [0.000, 5.000],  loss: 0.007721, mean_q: 0.274936, mean_eps: 0.514312
#  122157/200000: episode: 181, duration: 62.278s, episode steps: 390, steps per second:   6, episode reward:  5.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.679 [0.000, 5.000],  loss: 0.007549, mean_q: 0.278871, mean_eps: 0.512154
#  123268/200000: episode: 182, duration: 176.787s, episode steps: 1111, steps per second:   6, episode reward: 17.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.751 [0.000, 5.000],  loss: 0.007690, mean_q: 0.278142, mean_eps: 0.509152
#  123773/200000: episode: 183, duration: 80.314s, episode steps: 505, steps per second:   6, episode reward:  5.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.861 [0.000, 5.000],  loss: 0.006929, mean_q: 0.273720, mean_eps: 0.505920
#  124633/200000: episode: 184, duration: 136.749s, episode steps: 860, steps per second:   6, episode reward: 14.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.433 [0.000, 5.000],  loss: 0.006697, mean_q: 0.272818, mean_eps: 0.503190
#  125097/200000: episode: 185, duration: 73.814s, episode steps: 464, steps per second:   6, episode reward:  9.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.625 [0.000, 5.000],  loss: 0.007412, mean_q: 0.279988, mean_eps: 0.500542
#  126073/200000: episode: 186, duration: 155.284s, episode steps: 976, steps per second:   6, episode reward: 17.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.655 [0.000, 5.000],  loss: 0.006372, mean_q: 0.276203, mean_eps: 0.497662
#  127093/200000: episode: 187, duration: 162.083s, episode steps: 1020, steps per second:   6, episode reward: 17.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.851 [0.000, 5.000],  loss: 0.006190, mean_q: 0.276448, mean_eps: 0.493670
#  127786/200000: episode: 188, duration: 110.211s, episode steps: 693, steps per second:   6, episode reward: 11.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.561 [0.000, 5.000],  loss: 0.005882, mean_q: 0.271262, mean_eps: 0.490244
#  128321/200000: episode: 189, duration: 85.403s, episode steps: 535, steps per second:   6, episode reward:  8.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.402 [0.000, 5.000],  loss: 0.005733, mean_q: 0.275763, mean_eps: 0.487788
#  128903/200000: episode: 190, duration: 92.787s, episode steps: 582, steps per second:   6, episode reward:  5.000, mean reward:  0.009 [ 0.000,  1.000], mean action: 2.476 [0.000, 5.000],  loss: 0.005903, mean_q: 0.272025, mean_eps: 0.485554
#  129514/200000: episode: 191, duration: 97.423s, episode steps: 611, steps per second:   6, episode reward:  8.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.799 [0.000, 5.000],  loss: 0.005404, mean_q: 0.273764, mean_eps: 0.483168
#  130183/200000: episode: 192, duration: 106.685s, episode steps: 669, steps per second:   6, episode reward: 12.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.546 [0.000, 5.000],  loss: 0.006221, mean_q: 0.282970, mean_eps: 0.480608
#  130721/200000: episode: 193, duration: 85.516s, episode steps: 538, steps per second:   6, episode reward:  6.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.522 [0.000, 5.000],  loss: 0.010139, mean_q: 0.313455, mean_eps: 0.478194
#  131335/200000: episode: 194, duration: 97.515s, episode steps: 614, steps per second:   6, episode reward:  8.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.593 [0.000, 5.000],  loss: 0.008971, mean_q: 0.314052, mean_eps: 0.475890
#  132482/200000: episode: 195, duration: 181.893s, episode steps: 1147, steps per second:   6, episode reward: 17.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.538 [0.000, 5.000],  loss: 0.008783, mean_q: 0.312181, mean_eps: 0.472368
#  133193/200000: episode: 196, duration: 113.062s, episode steps: 711, steps per second:   6, episode reward:  8.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.470 [0.000, 5.000],  loss: 0.007490, mean_q: 0.313056, mean_eps: 0.468652
#  133623/200000: episode: 197, duration: 68.774s, episode steps: 430, steps per second:   6, episode reward:  7.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.400 [0.000, 5.000],  loss: 0.007376, mean_q: 0.307656, mean_eps: 0.466370
#  134268/200000: episode: 198, duration: 102.803s, episode steps: 645, steps per second:   6, episode reward: 11.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.702 [0.000, 5.000],  loss: 0.007313, mean_q: 0.311030, mean_eps: 0.464220
# ...
#  160406/200000: episode: 242, duration: 76.527s, episode steps: 475, steps per second:   6, episode reward:  6.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.728 [0.000, 5.000],  loss: 0.008934, mean_q: 0.363711, mean_eps: 0.359328
#  160956/200000: episode: 243, duration: 88.446s, episode steps: 550, steps per second:   6, episode reward:  9.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.364 [0.000, 5.000],  loss: 0.009079, mean_q: 0.374885, mean_eps: 0.357278
#  161571/200000: episode: 244, duration: 98.840s, episode steps: 615, steps per second:   6, episode reward:  8.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.410 [0.000, 5.000],  loss: 0.008219, mean_q: 0.369579, mean_eps: 0.354948
#  162445/200000: episode: 245, duration: 140.732s, episode steps: 874, steps per second:   6, episode reward: 20.000, mean reward:  0.023 [ 0.000,  1.000], mean action: 2.341 [0.000, 5.000],  loss: 0.009515, mean_q: 0.379538, mean_eps: 0.351970
#  162991/200000: episode: 246, duration: 87.838s, episode steps: 546, steps per second:   6, episode reward:  9.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.815 [0.000, 5.000],  loss: 0.008568, mean_q: 0.371805, mean_eps: 0.349130
#  163647/200000: episode: 247, duration: 105.409s, episode steps: 656, steps per second:   6, episode reward: 10.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.665 [0.000, 5.000],  loss: 0.008334, mean_q: 0.373254, mean_eps: 0.346726
#  164189/200000: episode: 248, duration: 87.187s, episode steps: 542, steps per second:   6, episode reward:  9.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.129 [0.000, 5.000],  loss: 0.007315, mean_q: 0.375409, mean_eps: 0.344330
#  164767/200000: episode: 249, duration: 93.097s, episode steps: 578, steps per second:   6, episode reward:  9.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.661 [0.000, 5.000],  loss: 0.007842, mean_q: 0.376438, mean_eps: 0.342090
#  165317/200000: episode: 250, duration: 88.473s, episode steps: 550, steps per second:   6, episode reward: 12.000, mean reward:  0.022 [ 0.000,  1.000], mean action: 2.584 [0.000, 5.000],  loss: 0.007717, mean_q: 0.373779, mean_eps: 0.339834
#  166142/200000: episode: 251, duration: 132.873s, episode steps: 825, steps per second:   6, episode reward: 13.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.331 [0.000, 5.000],  loss: 0.007531, mean_q: 0.369893, mean_eps: 0.337084
#  166806/200000: episode: 252, duration: 107.102s, episode steps: 664, steps per second:   6, episode reward:  8.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.300 [0.000, 5.000],  loss: 0.007132, mean_q: 0.367467, mean_eps: 0.334106
#  167516/200000: episode: 253, duration: 114.186s, episode steps: 710, steps per second:   6, episode reward: 11.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.294 [0.000, 5.000],  loss: 0.007034, mean_q: 0.375699, mean_eps: 0.331358
#  168034/200000: episode: 254, duration: 83.546s, episode steps: 518, steps per second:   6, episode reward:  6.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.369 [0.000, 5.000],  loss: 0.007949, mean_q: 0.376798, mean_eps: 0.328902
#  168422/200000: episode: 255, duration: 62.540s, episode steps: 388, steps per second:   6, episode reward:  6.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.410 [0.000, 5.000],  loss: 0.007436, mean_q: 0.371261, mean_eps: 0.327090
#  168857/200000: episode: 256, duration: 70.223s, episode steps: 435, steps per second:   6, episode reward:  8.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.717 [0.000, 5.000],  loss: 0.006163, mean_q: 0.367521, mean_eps: 0.325444
#  169482/200000: episode: 257, duration: 100.829s, episode steps: 625, steps per second:   6, episode reward: 11.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.682 [0.000, 5.000],  loss: 0.007441, mean_q: 0.373398, mean_eps: 0.323324
#  170308/200000: episode: 258, duration: 133.009s, episode steps: 826, steps per second:   6, episode reward: 16.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.580 [0.000, 5.000],  loss: 0.007022, mean_q: 0.377303, mean_eps: 0.320422
#  170847/200000: episode: 259, duration: 86.722s, episode steps: 539, steps per second:   6, episode reward:  8.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.430 [0.000, 5.000],  loss: 0.007270, mean_q: 0.380860, mean_eps: 0.317692
#  171245/200000: episode: 260, duration: 64.148s, episode steps: 398, steps per second:   6, episode reward:  5.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.975 [0.000, 5.000],  loss: 0.007479, mean_q: 0.379821, mean_eps: 0.315818
#  172059/200000: episode: 261, duration: 130.729s, episode steps: 814, steps per second:   6, episode reward: 17.000, mean reward:  0.021 [ 0.000,  1.000], mean action: 2.921 [0.000, 5.000],  loss: 0.007853, mean_q: 0.382040, mean_eps: 0.313394
#  172979/200000: episode: 262, duration: 148.182s, episode steps: 920, steps per second:   6, episode reward: 16.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.827 [0.000, 5.000],  loss: 0.007583, mean_q: 0.383148, mean_eps: 0.309926
#  173776/200000: episode: 263, duration: 128.590s, episode steps: 797, steps per second:   6, episode reward: 15.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.404 [0.000, 5.000],  loss: 0.007969, mean_q: 0.385487, mean_eps: 0.306492
#  174415/200000: episode: 264, duration: 103.290s, episode steps: 639, steps per second:   6, episode reward: 11.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.886 [0.000, 5.000],  loss: 0.007977, mean_q: 0.375865, mean_eps: 0.303620
#  175390/200000: episode: 265, duration: 157.122s, episode steps: 975, steps per second:   6, episode reward: 13.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 3.054 [0.000, 5.000],  loss: 0.007073, mean_q: 0.386432, mean_eps: 0.300392
#  175928/200000: episode: 266, duration: 86.859s, episode steps: 538, steps per second:   6, episode reward: 10.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.608 [0.000, 5.000],  loss: 0.006974, mean_q: 0.377892, mean_eps: 0.297366
#  176454/200000: episode: 267, duration: 85.195s, episode steps: 526, steps per second:   6, episode reward: 10.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.721 [0.000, 5.000],  loss: 0.006487, mean_q: 0.381508, mean_eps: 0.295238
#  176970/200000: episode: 268, duration: 83.863s, episode steps: 516, steps per second:   6, episode reward:  8.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.919 [0.000, 5.000],  loss: 0.006847, mean_q: 0.378127, mean_eps: 0.293154
#  177652/200000: episode: 269, duration: 110.079s, episode steps: 682, steps per second:   6, episode reward: 15.000, mean reward:  0.022 [ 0.000,  1.000], mean action: 2.589 [0.000, 5.000],  loss: 0.006431, mean_q: 0.378923, mean_eps: 0.290758
#  178181/200000: episode: 270, duration: 85.794s, episode steps: 529, steps per second:   6, episode reward:  8.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.781 [0.000, 5.000],  loss: 0.006062, mean_q: 0.372861, mean_eps: 0.288336
#  178853/200000: episode: 271, duration: 108.774s, episode steps: 672, steps per second:   6, episode reward: 11.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.729 [0.000, 5.000],  loss: 0.006340, mean_q: 0.382436, mean_eps: 0.285934
#  179497/200000: episode: 272, duration: 104.048s, episode steps: 644, steps per second:   6, episode reward: 12.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.916 [0.000, 5.000],  loss: 0.005857, mean_q: 0.380951, mean_eps: 0.283302
#  179897/200000: episode: 273, duration: 65.033s, episode steps: 400, steps per second:   6, episode reward:  5.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 3.038 [0.000, 5.000],  loss: 0.006274, mean_q: 0.384488, mean_eps: 0.281214
#  180386/200000: episode: 274, duration: 79.612s, episode steps: 489, steps per second:   6, episode reward:  8.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 3.055 [0.000, 5.000],  loss: 0.007376, mean_q: 0.413621, mean_eps: 0.279436
#  180991/200000: episode: 275, duration: 98.253s, episode steps: 605, steps per second:   6, episode reward:  3.000, mean reward:  0.005 [ 0.000,  1.000], mean action: 2.724 [0.000, 5.000],  loss: 0.008237, mean_q: 0.407162, mean_eps: 0.277248
#  181367/200000: episode: 276, duration: 61.444s, episode steps: 376, steps per second:   6, episode reward:  5.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.428 [0.000, 5.000],  loss: 0.009309, mean_q: 0.414916, mean_eps: 0.275286
#  182185/200000: episode: 277, duration: 133.938s, episode steps: 818, steps per second:   6, episode reward: 15.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.686 [0.000, 5.000],  loss: 0.007617, mean_q: 0.401669, mean_eps: 0.272898
#  182725/200000: episode: 278, duration: 87.807s, episode steps: 540, steps per second:   6, episode reward:  5.000, mean reward:  0.009 [ 0.000,  1.000], mean action: 2.533 [0.000, 5.000],  loss: 0.007113, mean_q: 0.401362, mean_eps: 0.270182
#  183088/200000: episode: 279, duration: 58.921s, episode steps: 363, steps per second:   6, episode reward:  6.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.829 [0.000, 5.000],  loss: 0.006514, mean_q: 0.398604, mean_eps: 0.268376
#  183841/200000: episode: 280, duration: 123.090s, episode steps: 753, steps per second:   6, episode reward: 13.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.583 [0.000, 5.000],  loss: 0.007305, mean_q: 0.407916, mean_eps: 0.266144
#  184398/200000: episode: 281, duration: 90.979s, episode steps: 557, steps per second:   6, episode reward:  5.000, mean reward:  0.009 [ 0.000,  1.000], mean action: 2.610 [0.000, 5.000],  loss: 0.006532, mean_q: 0.398872, mean_eps: 0.263524
#  184777/200000: episode: 282, duration: 61.731s, episode steps: 379, steps per second:   6, episode reward:  6.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.467 [0.000, 5.000],  loss: 0.007850, mean_q: 0.400118, mean_eps: 0.261652
#  185185/200000: episode: 283, duration: 66.581s, episode steps: 408, steps per second:   6, episode reward:  7.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.103 [0.000, 5.000],  loss: 0.006718, mean_q: 0.404754, mean_eps: 0.260078
#  185853/200000: episode: 284, duration: 109.152s, episode steps: 668, steps per second:   6, episode reward: 10.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.740 [0.000, 5.000],  loss: 0.007041, mean_q: 0.403159, mean_eps: 0.257926
#  186193/200000: episode: 285, duration: 55.685s, episode steps: 340, steps per second:   6, episode reward:  4.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.968 [0.000, 5.000],  loss: 0.008506, mean_q: 0.407017, mean_eps: 0.255910
#  187009/200000: episode: 286, duration: 133.094s, episode steps: 816, steps per second:   6, episode reward:  9.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.616 [0.000, 5.000],  loss: 0.006588, mean_q: 0.398278, mean_eps: 0.253598
#  187363/200000: episode: 287, duration: 57.629s, episode steps: 354, steps per second:   6, episode reward:  6.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.780 [0.000, 5.000],  loss: 0.006129, mean_q: 0.405182, mean_eps: 0.251258
#  188030/200000: episode: 288, duration: 108.618s, episode steps: 667, steps per second:   6, episode reward: 12.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.577 [0.000, 5.000],  loss: 0.006532, mean_q: 0.402814, mean_eps: 0.249216
#  188980/200000: episode: 289, duration: 154.653s, episode steps: 950, steps per second:   6, episode reward: 25.000, mean reward:  0.026 [ 0.000,  1.000], mean action: 3.076 [0.000, 5.000],  loss: 0.006047, mean_q: 0.407725, mean_eps: 0.245982
#  190060/200000: episode: 290, duration: 175.630s, episode steps: 1080, steps per second:   6, episode reward: 26.000, mean reward:  0.024 [ 0.000,  1.000], mean action: 2.605 [0.000, 5.000],  loss: 0.006024, mean_q: 0.403427, mean_eps: 0.241922
#  190606/200000: episode: 291, duration: 88.953s, episode steps: 546, steps per second:   6, episode reward:  7.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.760 [0.000, 5.000],  loss: 0.008315, mean_q: 0.429522, mean_eps: 0.238670
#  191295/200000: episode: 292, duration: 112.083s, episode steps: 689, steps per second:   6, episode reward: 12.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.364 [0.000, 5.000],  loss: 0.008777, mean_q: 0.427456, mean_eps: 0.236200
#  191932/200000: episode: 293, duration: 103.830s, episode steps: 637, steps per second:   6, episode reward: 11.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.460 [0.000, 5.000],  loss: 0.008734, mean_q: 0.429855, mean_eps: 0.233548
#  192541/200000: episode: 294, duration: 99.122s, episode steps: 609, steps per second:   6, episode reward: 12.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.420 [0.000, 5.000],  loss: 0.008236, mean_q: 0.425559, mean_eps: 0.231056
#  193070/200000: episode: 295, duration: 86.179s, episode steps: 529, steps per second:   6, episode reward:  9.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 3.378 [0.000, 5.000],  loss: 0.007333, mean_q: 0.426222, mean_eps: 0.228780
#  193588/200000: episode: 296, duration: 84.386s, episode steps: 518, steps per second:   6, episode reward:  1.000, mean reward:  0.002 [ 0.000,  1.000], mean action: 2.448 [0.000, 5.000],  loss: 0.008068, mean_q: 0.424971, mean_eps: 0.226686
#  194110/200000: episode: 297, duration: 84.853s, episode steps: 522, steps per second:   6, episode reward:  6.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.366 [0.000, 5.000],  loss: 0.007746, mean_q: 0.420721, mean_eps: 0.224606
#  194731/200000: episode: 298, duration: 100.901s, episode steps: 621, steps per second:   6, episode reward:  7.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.853 [0.000, 5.000],  loss: 0.006985, mean_q: 0.424488, mean_eps: 0.222320
#  195367/200000: episode: 299, duration: 103.382s, episode steps: 636, steps per second:   6, episode reward: 10.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.791 [0.000, 5.000],  loss: 0.008556, mean_q: 0.431574, mean_eps: 0.219806
#  195974/200000: episode: 300, duration: 98.693s, episode steps: 607, steps per second:   6, episode reward:  8.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.707 [0.000, 5.000],  loss: 0.007609, mean_q: 0.428079, mean_eps: 0.217320
#  196343/200000: episode: 301, duration: 60.005s, episode steps: 369, steps per second:   6, episode reward:  6.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 3.103 [0.000, 5.000],  loss: 0.007423, mean_q: 0.423796, mean_eps: 0.215368
#  197635/200000: episode: 302, duration: 209.751s, episode steps: 1292, steps per second:   6, episode reward: 21.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.462 [0.000, 5.000],  loss: 0.007052, mean_q: 0.424618, mean_eps: 0.212046
#  198325/200000: episode: 303, duration: 112.195s, episode steps: 690, steps per second:   6, episode reward: 11.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.568 [0.000, 5.000],  loss: 0.006226, mean_q: 0.421199, mean_eps: 0.208082
#  198988/200000: episode: 304, duration: 107.821s, episode steps: 663, steps per second:   6, episode reward: 10.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.653 [0.000, 5.000],  loss: 0.005811, mean_q: 0.417252, mean_eps: 0.205376
#  199561/200000: episode: 305, duration: 93.063s, episode steps: 573, steps per second:   6, episode reward: 11.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.604 [0.000, 5.000],  loss: 0.006732, mean_q: 0.431102, mean_eps: 0.202904
# Step 200000: saving model to checkpoints/dqn_v09_weights_200000.h5f
# done, took 28729.534 seconds
# ⏱ Tiempo de fin: 03:19:01
# [WARNING] dqn_09_weights.h5f.index already exists - overwrite? [y/n]y
# [TIP] Next time specify overwrite=True!

# %%
# Testing part to calculate the mean reward
#weights_filename = 'dqn_{}_weights.h5f'.format(env_name)
weights_filename = 'dqn_09_weights.h5f'.format(env_name)
dqn.load_weights(weights_filename)
dqn.test(env, nb_episodes=10, visualize=False)
# Out:
# Testing for 10 episodes ...
# Episode 1: reward: 21.000, steps: 895
# Episode 2: reward: 13.000, steps: 682
# Episode 3: reward: 7.000, steps: 394
# Episode 4: reward: 10.000, steps: 910
# Episode 5: reward: 21.000, steps: 909
# Episode 6: reward: 16.000, steps: 974
# Episode 7: reward: 12.000, steps: 644
# Episode 8: reward: 15.000, steps: 926
# Episode 9: reward: 14.000, steps: 920
# Episode 10: reward: 7.000, steps: 376

# %%
from google.colab import drive
import shutil
import glob  # <-- ¡Falta este import!
import os

# 1. Montar Google Drive
#drive.mount('/content/drive')

# 2. Crear directorio en Drive si no existe
os.makedirs('/content/gdrive/MyDrive/Colab_Outputs', exist_ok=True)

# 3. Buscar y copiar todos los archivos coincidentes
archivos = glob.glob('dqn_09_weights.h5f.*')  # Encuentra todos los archivos con ese patrón

for archivo in archivos:
    shutil.copy(
        archivo,
        f'/content/gdrive/MyDrive/Colab_Outputs/{os.path.basename(archivo)}'
    )
    print(f"¡Archivo {archivo} copiado a Drive!")

# 4. Buscar y copiar todos los archivos coincidentes
archivos = glob.glob('checkpoints/dqn_v09_weights*')  # Encuentra todos los archivos con ese patrón

for archivo in archivos:
    shutil.copy(
        archivo,
        f'/content/gdrive/MyDrive/Colab_Outputs/{os.path.basename(archivo)}'
    )

print("✅ ¡Todos los archivos copiados!")
# Out:
# ¡Archivo dqn_09_weights.h5f.data-00000-of-00001 copiado a Drive!
# ¡Archivo dqn_09_weights.h5f.index copiado a Drive!
# ✅ ¡Todos los archivos copiados!
