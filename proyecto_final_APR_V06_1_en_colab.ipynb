# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisIrigoyen/trabajo_final_RL/blob/main/proyecto_final_APR_V06_1_en_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1.2. Localizar entorno de trabajo: Google colab o local

# %%
# ATENCIÓN!! Modificar ruta relativa a la práctica si es distinta (drive_root)
mount='/content/gdrive'
drive_root = mount + "/My Drive/08_MIAR/actividades/proyecto practico"

try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False

# %% [markdown]
# ## 1.3. Montar carpeta de datos local (solo Colab)

# %%
# Switch to the directory on the Google Drive that you want to use
import os
if IN_COLAB:
  print("We're running Colab")

  if IN_COLAB:
    # Mount the Google Drive at mount
    print("Colab: mounting Google drive on ", mount)

    drive.mount(mount)

    # Create drive_root if it doesn't exist
    create_drive_root = True
    if create_drive_root:
      print("\nColab: making sure ", drive_root, " exists.")
      os.makedirs(drive_root, exist_ok=True)

    # Change to the directory
    print("\nColab: Changing directory to ", drive_root)
    # %cd $drive_root
# Verify we're in the correct working directory
# %pwd
print("Archivos en el directorio: ")
print(os.listdir())
# Out:
# We're running Colab
# Colab: mounting Google drive on  /content/gdrive
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#
# Colab: making sure  /content/gdrive/My Drive/08_MIAR/actividades/proyecto practico  exists.
#
# Colab: Changing directory to  /content/gdrive/My Drive/08_MIAR/actividades/proyecto practico
# /content/gdrive/My Drive/08_MIAR/actividades/proyecto practico
# Archivos en el directorio:
# ['dqn_models', 'checkpoints', 'dqn_05_weights.h5f.data-00000-of-00001', 'dqn_05_weights.h5f.index', 'dqn_06_weights.h5f.index', 'dqn_06_weights.h5f.data-00000-of-00001', 'dqn_07_weights.h5f.index', 'dqn_07_weights.h5f.data-00000-of-00001', 'dqn_09_weights.h5f.data-00000-of-00001', 'dqn_09_weights.h5f.index', 'dqn_08_weights.h5f.data-00000-of-00001', 'dqn_08_weights.h5f.index', 'checkpoint']

# %% [markdown]
# ## 1.4. Instalar librerías necesarias

# %%
if IN_COLAB:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install keras-rl2==1.0.5
  # %pip install tensorflow==2.12  #2.8
else:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install pyglet==1.5.0
  # %pip install h5py==3.1.0
  # %pip install Pillow==9.5.0
  # %pip install keras-rl3
  # %pip install Keras==2.2.4
  # %pip install tensorflow==2.10.1
  # %pip install torch==2.0.1
  # %pip install agents==1.4.0
# Out:
# Requirement already satisfied: gym==0.17.3 in /usr/local/lib/python3.11/dist-packages (0.17.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.15.3)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.23.5)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.6.0)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym==0.17.3) (1.0.0)
# Collecting git+https://github.com/Kojoley/atari-py.git
#   Cloning https://github.com/Kojoley/atari-py.git to /tmp/pip-req-build-_9jxwkz7
#   Running command git clone --filter=blob:none --quiet https://github.com/Kojoley/atari-py.git /tmp/pip-req-build-_9jxwkz7
#   Resolved https://github.com/Kojoley/atari-py.git to commit 86a1e05c0a95e9e6233c3a413521fdb34ca8a089
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from atari-py==1.2.2) (1.23.5)
# Requirement already satisfied: keras-rl2==1.0.5 in /usr/local/lib/python3.11/dist-packages (1.0.5)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (from keras-rl2==1.0.5) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.73.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.14.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.4.30)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (18.1.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (4.25.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.17.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (4.14.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow->keras-rl2==1.0.5) (0.45.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow->keras-rl2==1.0.5) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow->keras-rl2==1.0.5) (0.4.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow->keras-rl2==1.0.5) (1.15.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.2.2)
# Requirement already satisfied: tensorflow==2.12 in /usr/local/lib/python3.11/dist-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.73.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (3.14.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (0.4.30)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (18.1.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (4.25.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.17.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (4.14.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.12) (0.45.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12) (0.4.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12) (1.15.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (3.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow==2.12) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12) (3.2.2)

# %% [markdown]
# ## **PARTE 3**. Desarrollo y preguntas
# Importar librerías

# %%
from __future__ import division

from PIL import Image
import numpy as np
import gym

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Convolution2D, Permute, BatchNormalization
#from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

# %% [markdown]
# #### Configuración base

# %%
INPUT_SHAPE = (84, 84)
WINDOW_LENGTH = 4

env_name = 'SpaceInvaders-v0'
env = gym.make(env_name)

np.random.seed(123)
env.seed(123)
nb_actions = env.action_space.n

#--- nuevo -- ejfm
height, width, channels = env.observation_space.shape
obs = env.reset()
print(height, width, channels)
print("Forma de la observación:", obs.shape)  # Debe ser (height, width, channels)
env.unwrapped.get_action_meanings()
# Out:
# 210 160 3
# Forma de la observación: (210, 160, 3)
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'RIGHTFIRE', 'LEFTFIRE']

# %%
class AtariProcessor(Processor):
    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)
        img = Image.fromarray(observation)
        img = img.resize(INPUT_SHAPE).convert('L')
        processed_observation = np.array(img)
        assert processed_observation.shape == INPUT_SHAPE
        return processed_observation.astype('uint8')

    def process_state_batch(self, batch):

        # ejfm -- modificado
        # Agrega la dimensión de canales (axis=-1) si no está presente
        if batch.ndim == 4:                         # Forma: (batch_size, window_length, h, w)
            batch = np.expand_dims(batch, axis=-1)  # Nueva forma: (batch_size, window_length, h, w, 1)
            processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return np.clip(reward, -1., 1.)

# %% [markdown]
# ## 1. EJFM Implementación de la red neuronal

# %%
# Habilita estas opciones ANTES de crear el modelo
import tensorflow as tf

physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    tf.config.optimizer.set_jit(True)  # Habilita XLA para aceleración

# Aceleración XLA (compilación optimizada)
tf.config.optimizer.set_jit(True)

# %%
def build_model(height, width, channels, actions):
    model = Sequential()

    # Capa 1: Conv2D y ReLU
    model.add(Convolution2D(32, (8, 8), strides=4, padding='same', input_shape=(4,84,84,1)))
    model.add(Activation('relu'))

    # Capa 2: Conv2D con BatchNorm y ReLU
    model.add(Convolution2D(64, (4, 4), strides=2, padding='same'))
    model.add(Activation('relu'))

    # Capa 3: Conv2D  y ReLU
    model.add(Convolution2D(64, (3, 3), padding='same'))
    model.add(Activation('relu'))

    # Aplanar + Capas Dense
    model.add(Flatten())

    model.add(Dense(512))
    model.add(Activation('relu'))

    model.add(Dense(256))
    model.add(Activation('relu'))

    # Capa de salida
    model.add(Dense(actions, activation='linear'))

    return model

model = build_model(84, 84, 1, nb_actions)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 4, 21, 21, 32)     2080
#
#  activation (Activation)     (None, 4, 21, 21, 32)     0
#
#  conv2d_1 (Conv2D)           (None, 4, 11, 11, 64)     32832
#
#  activation_1 (Activation)   (None, 4, 11, 11, 64)     0
#
#  conv2d_2 (Conv2D)           (None, 4, 11, 11, 64)     36928
#
#  activation_2 (Activation)   (None, 4, 11, 11, 64)     0
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 512)               15860224
#
#  activation_3 (Activation)   (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dense_2 (Dense)             (None, 6)                 1542
#
# =================================================================
# Total params: 16,064,934
# Trainable params: 16,064,934
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 2. EJFM Implementación de la solución DQN

# %%
from rl.agents import DQNAgent
from rl.memory import SequentialMemory
from rl.policy import LinearAnnealedPolicy, EpsGreedyQPolicy
from keras.optimizers import Adam

def build_agent(model, actions):
    policy = LinearAnnealedPolicy(
        EpsGreedyQPolicy(),
        attr='eps',
        value_max=1.0,
        value_min=0.2,
        value_test=0.1, nb_steps=200000)
    memory = SequentialMemory(limit=200000, window_length=4)
    dqn = DQNAgent(model=model,
                   memory=memory,
                   policy=policy,
                   enable_double_dqn=True,
                   enable_dueling_network=True,
                   dueling_type='avg',
                   nb_actions=nb_actions,
                   batch_size=32,
                   target_model_update=10000,
                   processor=AtariProcessor(),
                   nb_steps_warmup=10000
                  )
    return dqn

dqn = build_agent(model, nb_actions)
dqn.compile(Adam(learning_rate=0.00025, epsilon=1e-4))

# %%
from rl.callbacks import ModelIntervalCheckpoint

# Guardar el modelo cada 25,000 pasos
checkpoint_callback = ModelIntervalCheckpoint(
    filepath='checkpoints/dqn_v06_1_weights_{step}.h5f',
    interval=25000,
    verbose=1
)

import os
os.makedirs("checkpoints", exist_ok=True)

# %%
from datetime import datetime

print(f"⏱ Tiempo de inicio: {datetime.now().strftime('%H:%M:%S')}")

dqn.fit(env, nb_steps=300000, visualize=False, verbose=2,callbacks=[checkpoint_callback])

print(f"⏱ Tiempo de fin: {datetime.now().strftime('%H:%M:%S')}")

# Guardando modelo
dqn.save_weights('dqn_06_1_weights.h5f')
# Out:
# ⏱ Tiempo de inicio: 20:56:32
# Training for 300000 steps ...
#     397/300000: episode: 1, duration: 2.321s, episode steps: 397, steps per second: 171, episode reward:  5.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.446 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    1143/300000: episode: 2, duration: 4.362s, episode steps: 746, steps per second: 171, episode reward:  9.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.462 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    1765/300000: episode: 3, duration: 3.524s, episode steps: 622, steps per second: 176, episode reward:  6.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.576 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    2161/300000: episode: 4, duration: 2.255s, episode steps: 396, steps per second: 176, episode reward:  4.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.439 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    2565/300000: episode: 5, duration: 2.299s, episode steps: 404, steps per second: 176, episode reward:  5.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.658 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    3186/300000: episode: 6, duration: 3.628s, episode steps: 621, steps per second: 171, episode reward:  6.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.565 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    3558/300000: episode: 7, duration: 2.148s, episode steps: 372, steps per second: 173, episode reward:  6.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.487 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    4259/300000: episode: 8, duration: 4.018s, episode steps: 701, steps per second: 174, episode reward: 13.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.524 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    4777/300000: episode: 9, duration: 2.994s, episode steps: 518, steps per second: 173, episode reward:  8.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.504 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    5487/300000: episode: 10, duration: 4.189s, episode steps: 710, steps per second: 169, episode reward: 10.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.420 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    6072/300000: episode: 11, duration: 3.344s, episode steps: 585, steps per second: 175, episode reward:  8.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.600 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    6695/300000: episode: 12, duration: 3.520s, episode steps: 623, steps per second: 177, episode reward:  8.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.568 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    7240/300000: episode: 13, duration: 3.114s, episode steps: 545, steps per second: 175, episode reward:  6.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.539 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    7771/300000: episode: 14, duration: 3.091s, episode steps: 531, steps per second: 172, episode reward:  6.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.501 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    8638/300000: episode: 15, duration: 4.892s, episode steps: 867, steps per second: 177, episode reward: 15.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.448 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    9463/300000: episode: 16, duration: 4.723s, episode steps: 825, steps per second: 175, episode reward:  8.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.481 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   10420/300000: episode: 17, duration: 69.835s, episode steps: 957, steps per second:  14, episode reward: 16.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.460 [0.000, 5.000],  loss: 0.007771, mean_q: 0.042701, mean_eps: 0.959160
#   11045/300000: episode: 18, duration: 99.221s, episode steps: 625, steps per second:   6, episode reward: 10.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.485 [0.000, 5.000],  loss: 0.006736, mean_q: 0.040444, mean_eps: 0.957072
#   11402/300000: episode: 19, duration: 56.752s, episode steps: 357, steps per second:   6, episode reward:  7.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.373 [0.000, 5.000],  loss: 0.006426, mean_q: 0.038075, mean_eps: 0.955108
#   11786/300000: episode: 20, duration: 61.018s, episode steps: 384, steps per second:   6, episode reward:  4.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.505 [0.000, 5.000],  loss: 0.007398, mean_q: 0.042486, mean_eps: 0.953626
#   12365/300000: episode: 21, duration: 91.114s, episode steps: 579, steps per second:   6, episode reward:  8.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.535 [0.000, 5.000],  loss: 0.006932, mean_q: 0.041012, mean_eps: 0.951700
#   12978/300000: episode: 22, duration: 96.114s, episode steps: 613, steps per second:   6, episode reward:  7.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.450 [0.000, 5.000],  loss: 0.006848, mean_q: 0.044607, mean_eps: 0.949316
#   13385/300000: episode: 23, duration: 64.090s, episode steps: 407, steps per second:   6, episode reward:  4.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.509 [0.000, 5.000],  loss: 0.006643, mean_q: 0.044351, mean_eps: 0.947276
#   13784/300000: episode: 24, duration: 62.714s, episode steps: 399, steps per second:   6, episode reward:  3.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 2.464 [0.000, 5.000],  loss: 0.006146, mean_q: 0.040102, mean_eps: 0.945664
#   14412/300000: episode: 25, duration: 99.023s, episode steps: 628, steps per second:   6, episode reward: 12.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.489 [0.000, 5.000],  loss: 0.006892, mean_q: 0.041692, mean_eps: 0.943610
#   15372/300000: episode: 26, duration: 150.562s, episode steps: 960, steps per second:   6, episode reward: 16.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.525 [0.000, 5.000],  loss: 0.006753, mean_q: 0.041707, mean_eps: 0.940434
#   15927/300000: episode: 27, duration: 87.773s, episode steps: 555, steps per second:   6, episode reward:  8.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.476 [0.000, 5.000],  loss: 0.007121, mean_q: 0.041881, mean_eps: 0.937404
#   16643/300000: episode: 28, duration: 112.295s, episode steps: 716, steps per second:   6, episode reward:  7.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.535 [0.000, 5.000],  loss: 0.007269, mean_q: 0.049651, mean_eps: 0.934862
#   17486/300000: episode: 29, duration: 132.416s, episode steps: 843, steps per second:   6, episode reward: 13.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.520 [0.000, 5.000],  loss: 0.006208, mean_q: 0.043808, mean_eps: 0.931744
#   18403/300000: episode: 30, duration: 144.036s, episode steps: 917, steps per second:   6, episode reward: 13.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.556 [0.000, 5.000],  loss: 0.006732, mean_q: 0.047062, mean_eps: 0.928224
#   19106/300000: episode: 31, duration: 110.263s, episode steps: 703, steps per second:   6, episode reward:  8.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.454 [0.000, 5.000],  loss: 0.006348, mean_q: 0.047171, mean_eps: 0.924984
#   19729/300000: episode: 32, duration: 98.307s, episode steps: 623, steps per second:   6, episode reward: 10.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.571 [0.000, 5.000],  loss: 0.006215, mean_q: 0.048797, mean_eps: 0.922332
#   20502/300000: episode: 33, duration: 121.573s, episode steps: 773, steps per second:   6, episode reward: 12.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.453 [0.000, 5.000],  loss: 0.007047, mean_q: 0.071566, mean_eps: 0.919540
#   20887/300000: episode: 34, duration: 60.432s, episode steps: 385, steps per second:   6, episode reward:  5.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.442 [0.000, 5.000],  loss: 0.006439, mean_q: 0.077153, mean_eps: 0.917224
#   21677/300000: episode: 35, duration: 123.992s, episode steps: 790, steps per second:   6, episode reward: 11.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.461 [0.000, 5.000],  loss: 0.006261, mean_q: 0.078632, mean_eps: 0.914874
#   22316/300000: episode: 36, duration: 100.638s, episode steps: 639, steps per second:   6, episode reward:  9.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.520 [0.000, 5.000],  loss: 0.006712, mean_q: 0.082007, mean_eps: 0.912016
#   22771/300000: episode: 37, duration: 72.247s, episode steps: 455, steps per second:   6, episode reward:  7.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.332 [0.000, 5.000],  loss: 0.006948, mean_q: 0.082230, mean_eps: 0.909828
#   23635/300000: episode: 38, duration: 136.689s, episode steps: 864, steps per second:   6, episode reward: 12.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.484 [0.000, 5.000],  loss: 0.006046, mean_q: 0.079729, mean_eps: 0.907190
#   24555/300000: episode: 39, duration: 144.820s, episode steps: 920, steps per second:   6, episode reward: 15.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.470 [0.000, 5.000],  loss: 0.006341, mean_q: 0.082882, mean_eps: 0.903622
# Step 25000: saving model to checkpoints/dqn_v06_1_weights_25000.h5f
#   25073/300000: episode: 40, duration: 81.728s, episode steps: 518, steps per second:   6, episode reward:  6.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.492 [0.000, 5.000],  loss: 0.006488, mean_q: 0.084641, mean_eps: 0.900746
#   26048/300000: episode: 41, duration: 153.416s, episode steps: 975, steps per second:   6, episode reward:  8.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 2.497 [0.000, 5.000],  loss: 0.006152, mean_q: 0.082873, mean_eps: 0.897760
#   26618/300000: episode: 42, duration: 90.237s, episode steps: 570, steps per second:   6, episode reward:  2.000, mean reward:  0.004 [ 0.000,  1.000], mean action: 2.486 [0.000, 5.000],  loss: 0.005361, mean_q: 0.077739, mean_eps: 0.894670
#   26998/300000: episode: 43, duration: 59.785s, episode steps: 380, steps per second:   6, episode reward:  2.000, mean reward:  0.005 [ 0.000,  1.000], mean action: 2.771 [0.000, 5.000],  loss: 0.005862, mean_q: 0.082254, mean_eps: 0.892770
#   27576/300000: episode: 44, duration: 90.991s, episode steps: 578, steps per second:   6, episode reward: 10.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.460 [0.000, 5.000],  loss: 0.006263, mean_q: 0.083129, mean_eps: 0.890854
#   28274/300000: episode: 45, duration: 110.385s, episode steps: 698, steps per second:   6, episode reward: 11.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.537 [0.000, 5.000],  loss: 0.006062, mean_q: 0.084367, mean_eps: 0.888302
#   28855/300000: episode: 46, duration: 91.263s, episode steps: 581, steps per second:   6, episode reward:  8.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.620 [0.000, 5.000],  loss: 0.005568, mean_q: 0.082814, mean_eps: 0.885744
#   29420/300000: episode: 47, duration: 89.162s, episode steps: 565, steps per second:   6, episode reward:  7.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.566 [0.000, 5.000],  loss: 0.005381, mean_q: 0.078309, mean_eps: 0.883452
#   29967/300000: episode: 48, duration: 86.159s, episode steps: 547, steps per second:   6, episode reward:  7.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.393 [0.000, 5.000],  loss: 0.005714, mean_q: 0.084055, mean_eps: 0.881228
#   30475/300000: episode: 49, duration: 80.255s, episode steps: 508, steps per second:   6, episode reward:  6.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.622 [0.000, 5.000],  loss: 0.006906, mean_q: 0.127259, mean_eps: 0.879118
#   30863/300000: episode: 50, duration: 61.395s, episode steps: 388, steps per second:   6, episode reward:  7.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.472 [0.000, 5.000],  loss: 0.006822, mean_q: 0.125092, mean_eps: 0.877326
#   31735/300000: episode: 51, duration: 137.046s, episode steps: 872, steps per second:   6, episode reward: 12.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.508 [0.000, 5.000],  loss: 0.005800, mean_q: 0.118542, mean_eps: 0.874806
#   32459/300000: episode: 52, duration: 113.882s, episode steps: 724, steps per second:   6, episode reward:  6.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 2.536 [0.000, 5.000],  loss: 0.005995, mean_q: 0.119918, mean_eps: 0.871614
#   32990/300000: episode: 53, duration: 83.715s, episode steps: 531, steps per second:   6, episode reward:  2.000, mean reward:  0.004 [ 0.000,  1.000], mean action: 2.414 [0.000, 5.000],  loss: 0.005298, mean_q: 0.115531, mean_eps: 0.869104
#   33453/300000: episode: 54, duration: 72.808s, episode steps: 463, steps per second:   6, episode reward:  4.000, mean reward:  0.009 [ 0.000,  1.000], mean action: 2.488 [0.000, 5.000],  loss: 0.005877, mean_q: 0.124999, mean_eps: 0.867116
#   34158/300000: episode: 55, duration: 110.909s, episode steps: 705, steps per second:   6, episode reward: 10.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.488 [0.000, 5.000],  loss: 0.005291, mean_q: 0.120719, mean_eps: 0.864780
#   35253/300000: episode: 56, duration: 172.081s, episode steps: 1095, steps per second:   6, episode reward: 28.000, mean reward:  0.026 [ 0.000,  1.000], mean action: 2.508 [0.000, 5.000],  loss: 0.005416, mean_q: 0.119489, mean_eps: 0.861180
#   36028/300000: episode: 57, duration: 122.203s, episode steps: 775, steps per second:   6, episode reward: 12.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.541 [0.000, 5.000],  loss: 0.005308, mean_q: 0.118743, mean_eps: 0.857440
#   36805/300000: episode: 58, duration: 122.508s, episode steps: 777, steps per second:   6, episode reward:  7.000, mean reward:  0.009 [ 0.000,  1.000], mean action: 2.481 [0.000, 5.000],  loss: 0.005235, mean_q: 0.123130, mean_eps: 0.854336
#   37537/300000: episode: 59, duration: 115.445s, episode steps: 732, steps per second:   6, episode reward:  8.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.454 [0.000, 5.000],  loss: 0.004974, mean_q: 0.119124, mean_eps: 0.851318
#   39082/300000: episode: 60, duration: 243.059s, episode steps: 1545, steps per second:   6, episode reward: 15.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.507 [0.000, 5.000],  loss: 0.004471, mean_q: 0.117753, mean_eps: 0.846764
#   39725/300000: episode: 61, duration: 101.214s, episode steps: 643, steps per second:   6, episode reward:  7.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.398 [0.000, 5.000],  loss: 0.004409, mean_q: 0.117190, mean_eps: 0.842388
#   40813/300000: episode: 62, duration: 172.560s, episode steps: 1088, steps per second:   6, episode reward: 18.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.517 [0.000, 5.000],  loss: 0.005407, mean_q: 0.141750, mean_eps: 0.838926
#   41648/300000: episode: 63, duration: 131.982s, episode steps: 835, steps per second:   6, episode reward: 12.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.436 [0.000, 5.000],  loss: 0.005634, mean_q: 0.141936, mean_eps: 0.835080
#   42340/300000: episode: 64, duration: 109.363s, episode steps: 692, steps per second:   6, episode reward:  8.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.429 [0.000, 5.000],  loss: 0.005305, mean_q: 0.143424, mean_eps: 0.832026
#   42866/300000: episode: 65, duration: 83.334s, episode steps: 526, steps per second:   6, episode reward:  7.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.551 [0.000, 5.000],  loss: 0.004646, mean_q: 0.140977, mean_eps: 0.829590
#   43572/300000: episode: 66, duration: 111.543s, episode steps: 706, steps per second:   6, episode reward:  9.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.518 [0.000, 5.000],  loss: 0.005214, mean_q: 0.142174, mean_eps: 0.827126
#   44399/300000: episode: 67, duration: 130.813s, episode steps: 827, steps per second:   6, episode reward: 14.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.473 [0.000, 5.000],  loss: 0.004789, mean_q: 0.141849, mean_eps: 0.824060
#   45191/300000: episode: 68, duration: 124.856s, episode steps: 792, steps per second:   6, episode reward: 10.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.519 [0.000, 5.000],  loss: 0.004332, mean_q: 0.139909, mean_eps: 0.820822
#   45839/300000: episode: 69, duration: 102.344s, episode steps: 648, steps per second:   6, episode reward: 13.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.511 [0.000, 5.000],  loss: 0.004809, mean_q: 0.142698, mean_eps: 0.817942
#   46481/300000: episode: 70, duration: 101.726s, episode steps: 642, steps per second:   6, episode reward: 11.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.391 [0.000, 5.000],  loss: 0.004389, mean_q: 0.138702, mean_eps: 0.815362
#   47450/300000: episode: 71, duration: 153.193s, episode steps: 969, steps per second:   6, episode reward: 12.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.496 [0.000, 5.000],  loss: 0.004151, mean_q: 0.140905, mean_eps: 0.812140
#   48001/300000: episode: 72, duration: 87.136s, episode steps: 551, steps per second:   6, episode reward:  8.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.557 [0.000, 5.000],  loss: 0.004352, mean_q: 0.141512, mean_eps: 0.809100
#   48821/300000: episode: 73, duration: 130.022s, episode steps: 820, steps per second:   6, episode reward: 14.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.501 [0.000, 5.000],  loss: 0.004009, mean_q: 0.138977, mean_eps: 0.806358
#   49551/300000: episode: 74, duration: 115.392s, episode steps: 730, steps per second:   6, episode reward:  5.000, mean reward:  0.007 [ 0.000,  1.000], mean action: 2.426 [0.000, 5.000],  loss: 0.003643, mean_q: 0.137185, mean_eps: 0.803258
# Step 50000: saving model to checkpoints/dqn_v06_1_weights_50000.h5f
#   50538/300000: episode: 75, duration: 156.351s, episode steps: 987, steps per second:   6, episode reward: 16.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.618 [0.000, 5.000],  loss: 0.006608, mean_q: 0.174071, mean_eps: 0.799824
#   51225/300000: episode: 76, duration: 109.150s, episode steps: 687, steps per second:   6, episode reward:  9.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.528 [0.000, 5.000],  loss: 0.007361, mean_q: 0.192362, mean_eps: 0.796476
#   52004/300000: episode: 77, duration: 122.898s, episode steps: 779, steps per second:   6, episode reward: 14.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.470 [0.000, 5.000],  loss: 0.006342, mean_q: 0.190523, mean_eps: 0.793544
#   52729/300000: episode: 78, duration: 114.936s, episode steps: 725, steps per second:   6, episode reward: 13.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.385 [0.000, 5.000],  loss: 0.005785, mean_q: 0.188398, mean_eps: 0.790536
#   53225/300000: episode: 79, duration: 78.328s, episode steps: 496, steps per second:   6, episode reward:  8.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.577 [0.000, 5.000],  loss: 0.004826, mean_q: 0.181987, mean_eps: 0.788094
#   54201/300000: episode: 80, duration: 154.456s, episode steps: 976, steps per second:   6, episode reward: 19.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.513 [0.000, 5.000],  loss: 0.005325, mean_q: 0.184165, mean_eps: 0.785150
#   55047/300000: episode: 81, duration: 134.764s, episode steps: 846, steps per second:   6, episode reward: 16.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.541 [0.000, 5.000],  loss: 0.005073, mean_q: 0.185474, mean_eps: 0.781506
#   55546/300000: episode: 82, duration: 78.924s, episode steps: 499, steps per second:   6, episode reward:  8.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.567 [0.000, 5.000],  loss: 0.004578, mean_q: 0.179879, mean_eps: 0.778816
#   56750/300000: episode: 83, duration: 190.062s, episode steps: 1204, steps per second:   6, episode reward: 21.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.306 [0.000, 5.000],  loss: 0.004775, mean_q: 0.182864, mean_eps: 0.775410
#   57723/300000: episode: 84, duration: 153.636s, episode steps: 973, steps per second:   6, episode reward: 10.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.585 [0.000, 5.000],  loss: 0.004523, mean_q: 0.183077, mean_eps: 0.771056
#   58237/300000: episode: 85, duration: 81.334s, episode steps: 514, steps per second:   6, episode reward:  9.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.623 [0.000, 5.000],  loss: 0.004225, mean_q: 0.181234, mean_eps: 0.768082
#   58845/300000: episode: 86, duration: 96.157s, episode steps: 608, steps per second:   6, episode reward:  8.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.632 [0.000, 5.000],  loss: 0.004178, mean_q: 0.177556, mean_eps: 0.765838
#   59453/300000: episode: 87, duration: 96.000s, episode steps: 608, steps per second:   6, episode reward:  7.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.640 [0.000, 5.000],  loss: 0.004264, mean_q: 0.179204, mean_eps: 0.763406
#   60099/300000: episode: 88, duration: 102.309s, episode steps: 646, steps per second:   6, episode reward:  8.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.576 [0.000, 5.000],  loss: 0.005024, mean_q: 0.190777, mean_eps: 0.760898
#   61698/300000: episode: 89, duration: 253.549s, episode steps: 1599, steps per second:   6, episode reward: 15.000, mean reward:  0.009 [ 0.000,  1.000], mean action: 2.442 [0.000, 5.000],  loss: 0.007863, mean_q: 0.237740, mean_eps: 0.756408
#   62701/300000: episode: 90, duration: 159.333s, episode steps: 1003, steps per second:   6, episode reward: 18.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.552 [0.000, 5.000],  loss: 0.006178, mean_q: 0.230774, mean_eps: 0.751204
#   63197/300000: episode: 91, duration: 78.804s, episode steps: 496, steps per second:   6, episode reward:  5.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.490 [0.000, 5.000],  loss: 0.005595, mean_q: 0.233228, mean_eps: 0.748206
#   63882/300000: episode: 92, duration: 108.461s, episode steps: 685, steps per second:   6, episode reward: 12.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.517 [0.000, 5.000],  loss: 0.005779, mean_q: 0.227600, mean_eps: 0.745844
#   64974/300000: episode: 93, duration: 173.029s, episode steps: 1092, steps per second:   6, episode reward: 22.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.599 [0.000, 5.000],  loss: 0.005340, mean_q: 0.227105, mean_eps: 0.742290
#   66145/300000: episode: 94, duration: 185.155s, episode steps: 1171, steps per second:   6, episode reward: 18.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.500 [0.000, 5.000],  loss: 0.005253, mean_q: 0.231395, mean_eps: 0.737764
#   66724/300000: episode: 95, duration: 92.513s, episode steps: 579, steps per second:   6, episode reward: 10.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.492 [0.000, 5.000],  loss: 0.004642, mean_q: 0.231410, mean_eps: 0.734264
#   67222/300000: episode: 96, duration: 78.927s, episode steps: 498, steps per second:   6, episode reward:  7.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.639 [0.000, 5.000],  loss: 0.004599, mean_q: 0.228492, mean_eps: 0.732110
#   68138/300000: episode: 97, duration: 145.480s, episode steps: 916, steps per second:   6, episode reward: 13.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.499 [0.000, 5.000],  loss: 0.005032, mean_q: 0.228306, mean_eps: 0.729282
#   68697/300000: episode: 98, duration: 88.844s, episode steps: 559, steps per second:   6, episode reward:  9.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.565 [0.000, 5.000],  loss: 0.004281, mean_q: 0.221710, mean_eps: 0.726332
#   69461/300000: episode: 99, duration: 121.113s, episode steps: 764, steps per second:   6, episode reward:  9.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.651 [0.000, 5.000],  loss: 0.004266, mean_q: 0.225865, mean_eps: 0.723686
#   69983/300000: episode: 100, duration: 83.489s, episode steps: 522, steps per second:   6, episode reward:  7.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.720 [0.000, 5.000],  loss: 0.004301, mean_q: 0.225660, mean_eps: 0.721114
#   70592/300000: episode: 101, duration: 96.477s, episode steps: 609, steps per second:   6, episode reward:  7.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.571 [0.000, 5.000],  loss: 0.008535, mean_q: 0.268899, mean_eps: 0.718852
#   71340/300000: episode: 102, duration: 118.810s, episode steps: 748, steps per second:   6, episode reward:  9.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.396 [0.000, 5.000],  loss: 0.007247, mean_q: 0.260248, mean_eps: 0.716138
#   72020/300000: episode: 103, duration: 107.677s, episode steps: 680, steps per second:   6, episode reward:  8.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.518 [0.000, 5.000],  loss: 0.007139, mean_q: 0.266575, mean_eps: 0.713282
#   72463/300000: episode: 104, duration: 70.190s, episode steps: 443, steps per second:   6, episode reward:  4.000, mean reward:  0.009 [ 0.000,  1.000], mean action: 2.758 [0.000, 5.000],  loss: 0.006698, mean_q: 0.266529, mean_eps: 0.711036
#   73023/300000: episode: 105, duration: 88.905s, episode steps: 560, steps per second:   6, episode reward:  8.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.514 [0.000, 5.000],  loss: 0.005961, mean_q: 0.260919, mean_eps: 0.709030
#   73816/300000: episode: 106, duration: 125.730s, episode steps: 793, steps per second:   6, episode reward:  8.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.340 [0.000, 5.000],  loss: 0.006438, mean_q: 0.261293, mean_eps: 0.706324
#   74854/300000: episode: 107, duration: 164.476s, episode steps: 1038, steps per second:   6, episode reward: 22.000, mean reward:  0.021 [ 0.000,  1.000], mean action: 2.624 [0.000, 5.000],  loss: 0.005500, mean_q: 0.258383, mean_eps: 0.702662
# Step 75000: saving model to checkpoints/dqn_v06_1_weights_75000.h5f
#   75652/300000: episode: 108, duration: 126.682s, episode steps: 798, steps per second:   6, episode reward: 13.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.515 [0.000, 5.000],  loss: 0.005294, mean_q: 0.258914, mean_eps: 0.698990
#   76331/300000: episode: 109, duration: 108.101s, episode steps: 679, steps per second:   6, episode reward:  9.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.554 [0.000, 5.000],  loss: 0.005413, mean_q: 0.252514, mean_eps: 0.696036
#   77019/300000: episode: 110, duration: 109.471s, episode steps: 688, steps per second:   6, episode reward: 16.000, mean reward:  0.023 [ 0.000,  1.000], mean action: 2.674 [0.000, 5.000],  loss: 0.004916, mean_q: 0.256267, mean_eps: 0.693302
#   77719/300000: episode: 111, duration: 111.814s, episode steps: 700, steps per second:   6, episode reward:  8.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.579 [0.000, 5.000],  loss: 0.004822, mean_q: 0.256403, mean_eps: 0.690526
#   78465/300000: episode: 112, duration: 118.139s, episode steps: 746, steps per second:   6, episode reward: 11.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.534 [0.000, 5.000],  loss: 0.005121, mean_q: 0.254991, mean_eps: 0.687634
#   79004/300000: episode: 113, duration: 85.709s, episode steps: 539, steps per second:   6, episode reward:  6.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.481 [0.000, 5.000],  loss: 0.005494, mean_q: 0.254906, mean_eps: 0.685064
#   79726/300000: episode: 114, duration: 114.930s, episode steps: 722, steps per second:   6, episode reward:  9.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.374 [0.000, 5.000],  loss: 0.004627, mean_q: 0.254547, mean_eps: 0.682542
#   80152/300000: episode: 115, duration: 67.708s, episode steps: 426, steps per second:   6, episode reward:  3.000, mean reward:  0.007 [ 0.000,  1.000], mean action: 2.599 [0.000, 5.000],  loss: 0.006270, mean_q: 0.276825, mean_eps: 0.680246
#   80567/300000: episode: 116, duration: 65.894s, episode steps: 415, steps per second:   6, episode reward:  6.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.467 [0.000, 5.000],  loss: 0.007433, mean_q: 0.304449, mean_eps: 0.678564
#   81433/300000: episode: 117, duration: 137.561s, episode steps: 866, steps per second:   6, episode reward: 17.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.490 [0.000, 5.000],  loss: 0.006890, mean_q: 0.305765, mean_eps: 0.676002
#   81927/300000: episode: 118, duration: 78.233s, episode steps: 494, steps per second:   6, episode reward:  8.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.520 [0.000, 5.000],  loss: 0.006219, mean_q: 0.300828, mean_eps: 0.673282
#   82836/300000: episode: 119, duration: 144.716s, episode steps: 909, steps per second:   6, episode reward: 21.000, mean reward:  0.023 [ 0.000,  1.000], mean action: 2.535 [0.000, 5.000],  loss: 0.006068, mean_q: 0.304543, mean_eps: 0.670476
#   83329/300000: episode: 120, duration: 78.130s, episode steps: 493, steps per second:   6, episode reward:  8.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.639 [0.000, 5.000],  loss: 0.005591, mean_q: 0.301658, mean_eps: 0.667672
#   84045/300000: episode: 121, duration: 113.565s, episode steps: 716, steps per second:   6, episode reward: 11.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.433 [0.000, 5.000],  loss: 0.005681, mean_q: 0.302161, mean_eps: 0.665254
#   85022/300000: episode: 122, duration: 154.997s, episode steps: 977, steps per second:   6, episode reward: 17.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.488 [0.000, 5.000],  loss: 0.005264, mean_q: 0.303963, mean_eps: 0.661868
#   85556/300000: episode: 123, duration: 84.584s, episode steps: 534, steps per second:   6, episode reward:  8.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.470 [0.000, 5.000],  loss: 0.005420, mean_q: 0.308088, mean_eps: 0.658846
#   86505/300000: episode: 124, duration: 151.057s, episode steps: 949, steps per second:   6, episode reward: 21.000, mean reward:  0.022 [ 0.000,  1.000], mean action: 2.562 [0.000, 5.000],  loss: 0.004774, mean_q: 0.303055, mean_eps: 0.655880
#   87307/300000: episode: 125, duration: 127.248s, episode steps: 802, steps per second:   6, episode reward: 16.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.627 [0.000, 5.000],  loss: 0.004568, mean_q: 0.298221, mean_eps: 0.652378
#   87759/300000: episode: 126, duration: 71.799s, episode steps: 452, steps per second:   6, episode reward:  8.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.586 [0.000, 5.000],  loss: 0.004453, mean_q: 0.308195, mean_eps: 0.649870
#   88425/300000: episode: 127, duration: 105.842s, episode steps: 666, steps per second:   6, episode reward: 17.000, mean reward:  0.026 [ 0.000,  1.000], mean action: 2.746 [0.000, 5.000],  loss: 0.004348, mean_q: 0.299593, mean_eps: 0.647634
#   89072/300000: episode: 128, duration: 103.118s, episode steps: 647, steps per second:   6, episode reward: 12.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.376 [0.000, 5.000],  loss: 0.004606, mean_q: 0.300685, mean_eps: 0.645008
#   89685/300000: episode: 129, duration: 97.446s, episode steps: 613, steps per second:   6, episode reward:  7.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.794 [0.000, 5.000],  loss: 0.004519, mean_q: 0.297853, mean_eps: 0.642488
#   90179/300000: episode: 130, duration: 78.545s, episode steps: 494, steps per second:   6, episode reward:  7.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.698 [0.000, 5.000],  loss: 0.005899, mean_q: 0.318976, mean_eps: 0.640274
#   90665/300000: episode: 131, duration: 77.153s, episode steps: 486, steps per second:   6, episode reward:  6.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.593 [0.000, 5.000],  loss: 0.008699, mean_q: 0.346239, mean_eps: 0.638314
#   91786/300000: episode: 132, duration: 177.999s, episode steps: 1121, steps per second:   6, episode reward: 19.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.735 [0.000, 5.000],  loss: 0.007188, mean_q: 0.337718, mean_eps: 0.635100
#   92300/300000: episode: 133, duration: 81.724s, episode steps: 514, steps per second:   6, episode reward:  6.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.691 [0.000, 5.000],  loss: 0.006572, mean_q: 0.335949, mean_eps: 0.631830
#   92918/300000: episode: 134, duration: 98.357s, episode steps: 618, steps per second:   6, episode reward:  9.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.472 [0.000, 5.000],  loss: 0.006478, mean_q: 0.343310, mean_eps: 0.629566
#   93853/300000: episode: 135, duration: 148.463s, episode steps: 935, steps per second:   6, episode reward: 15.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.465 [0.000, 5.000],  loss: 0.005684, mean_q: 0.337202, mean_eps: 0.626460
#   94309/300000: episode: 136, duration: 72.921s, episode steps: 456, steps per second:   6, episode reward:  8.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.351 [0.000, 5.000],  loss: 0.005724, mean_q: 0.335758, mean_eps: 0.623678
#   94995/300000: episode: 137, duration: 108.942s, episode steps: 686, steps per second:   6, episode reward: 12.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.544 [0.000, 5.000],  loss: 0.005449, mean_q: 0.338408, mean_eps: 0.621394
#   95394/300000: episode: 138, duration: 63.453s, episode steps: 399, steps per second:   6, episode reward:  7.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.687 [0.000, 5.000],  loss: 0.005658, mean_q: 0.341878, mean_eps: 0.619224
#   95871/300000: episode: 139, duration: 75.792s, episode steps: 477, steps per second:   6, episode reward:  3.000, mean reward:  0.006 [ 0.000,  1.000], mean action: 2.551 [0.000, 5.000],  loss: 0.005756, mean_q: 0.337884, mean_eps: 0.617472
#   96527/300000: episode: 140, duration: 104.615s, episode steps: 656, steps per second:   6, episode reward:  8.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.541 [0.000, 5.000],  loss: 0.005336, mean_q: 0.337653, mean_eps: 0.615206
#   96988/300000: episode: 141, duration: 73.698s, episode steps: 461, steps per second:   6, episode reward:  6.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.551 [0.000, 5.000],  loss: 0.005302, mean_q: 0.338602, mean_eps: 0.612972
#   97420/300000: episode: 142, duration: 69.049s, episode steps: 432, steps per second:   6, episode reward:  7.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.778 [0.000, 5.000],  loss: 0.004865, mean_q: 0.340774, mean_eps: 0.611186
#   98025/300000: episode: 143, duration: 96.338s, episode steps: 605, steps per second:   6, episode reward: 10.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.664 [0.000, 5.000],  loss: 0.005115, mean_q: 0.335222, mean_eps: 0.609112
#   98694/300000: episode: 144, duration: 107.131s, episode steps: 669, steps per second:   6, episode reward: 10.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.535 [0.000, 5.000],  loss: 0.004534, mean_q: 0.339543, mean_eps: 0.606564
#   99903/300000: episode: 145, duration: 191.829s, episode steps: 1209, steps per second:   6, episode reward: 22.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.474 [0.000, 5.000],  loss: 0.004485, mean_q: 0.332930, mean_eps: 0.602808
# Step 100000: saving model to checkpoints/dqn_v06_1_weights_100000.h5f
#  100583/300000: episode: 146, duration: 108.693s, episode steps: 680, steps per second:   6, episode reward: 15.000, mean reward:  0.022 [ 0.000,  1.000], mean action: 2.593 [0.000, 5.000],  loss: 0.007906, mean_q: 0.373963, mean_eps: 0.599030
#  101346/300000: episode: 147, duration: 121.228s, episode steps: 763, steps per second:   6, episode reward: 15.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.634 [0.000, 5.000],  loss: 0.008555, mean_q: 0.381188, mean_eps: 0.596144
#  101979/300000: episode: 148, duration: 101.157s, episode steps: 633, steps per second:   6, episode reward:  9.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.420 [0.000, 5.000],  loss: 0.007424, mean_q: 0.380950, mean_eps: 0.593352
#  103232/300000: episode: 149, duration: 199.483s, episode steps: 1253, steps per second:   6, episode reward: 15.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.535 [0.000, 5.000],  loss: 0.006967, mean_q: 0.373023, mean_eps: 0.589580
#  103789/300000: episode: 150, duration: 89.167s, episode steps: 557, steps per second:   6, episode reward:  6.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.531 [0.000, 5.000],  loss: 0.006418, mean_q: 0.377250, mean_eps: 0.585960
#  104464/300000: episode: 151, duration: 107.425s, episode steps: 675, steps per second:   6, episode reward: 10.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.490 [0.000, 5.000],  loss: 0.006420, mean_q: 0.369240, mean_eps: 0.583496
#  104894/300000: episode: 152, duration: 68.604s, episode steps: 430, steps per second:   6, episode reward:  8.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.512 [0.000, 5.000],  loss: 0.006238, mean_q: 0.374624, mean_eps: 0.581286
#  105380/300000: episode: 153, duration: 77.621s, episode steps: 486, steps per second:   6, episode reward:  8.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.687 [0.000, 5.000],  loss: 0.005943, mean_q: 0.378082, mean_eps: 0.579454
#  106251/300000: episode: 154, duration: 139.226s, episode steps: 871, steps per second:   6, episode reward: 13.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.346 [0.000, 5.000],  loss: 0.005575, mean_q: 0.367561, mean_eps: 0.576740
#  106657/300000: episode: 155, duration: 64.830s, episode steps: 406, steps per second:   6, episode reward:  7.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.500 [0.000, 5.000],  loss: 0.005456, mean_q: 0.370928, mean_eps: 0.574186
#  107368/300000: episode: 156, duration: 113.353s, episode steps: 711, steps per second:   6, episode reward: 15.000, mean reward:  0.021 [ 0.000,  1.000], mean action: 2.437 [0.000, 5.000],  loss: 0.005327, mean_q: 0.371288, mean_eps: 0.571952
#  107919/300000: episode: 157, duration: 87.828s, episode steps: 551, steps per second:   6, episode reward:  7.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.559 [0.000, 5.000],  loss: 0.005839, mean_q: 0.371604, mean_eps: 0.569428
#  108979/300000: episode: 158, duration: 169.122s, episode steps: 1060, steps per second:   6, episode reward: 18.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.701 [0.000, 5.000],  loss: 0.005206, mean_q: 0.368697, mean_eps: 0.566206
#  109390/300000: episode: 159, duration: 65.674s, episode steps: 411, steps per second:   6, episode reward:  5.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.662 [0.000, 5.000],  loss: 0.004994, mean_q: 0.373631, mean_eps: 0.563264
#  109892/300000: episode: 160, duration: 80.175s, episode steps: 502, steps per second:   6, episode reward:  4.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 2.584 [0.000, 5.000],  loss: 0.005263, mean_q: 0.375819, mean_eps: 0.561438
#  110500/300000: episode: 161, duration: 97.287s, episode steps: 608, steps per second:   6, episode reward: 10.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.610 [0.000, 5.000],  loss: 0.008352, mean_q: 0.409588, mean_eps: 0.559218
#  111334/300000: episode: 162, duration: 132.873s, episode steps: 834, steps per second:   6, episode reward: 15.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.673 [0.000, 5.000],  loss: 0.009050, mean_q: 0.419581, mean_eps: 0.556334
#  111721/300000: episode: 163, duration: 61.895s, episode steps: 387, steps per second:   6, episode reward:  8.000, mean reward:  0.021 [ 0.000,  1.000], mean action: 2.540 [0.000, 5.000],  loss: 0.008283, mean_q: 0.418068, mean_eps: 0.553892
#  112165/300000: episode: 164, duration: 71.045s, episode steps: 444, steps per second:   6, episode reward:  5.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.604 [0.000, 5.000],  loss: 0.007889, mean_q: 0.426306, mean_eps: 0.552230
#  113134/300000: episode: 165, duration: 154.657s, episode steps: 969, steps per second:   6, episode reward: 21.000, mean reward:  0.022 [ 0.000,  1.000], mean action: 2.389 [0.000, 5.000],  loss: 0.008271, mean_q: 0.422802, mean_eps: 0.549404
#  113742/300000: episode: 166, duration: 97.142s, episode steps: 608, steps per second:   6, episode reward:  7.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.653 [0.000, 5.000],  loss: 0.007736, mean_q: 0.419553, mean_eps: 0.546250
#  114107/300000: episode: 167, duration: 58.429s, episode steps: 365, steps per second:   6, episode reward:  6.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.589 [0.000, 5.000],  loss: 0.008225, mean_q: 0.418733, mean_eps: 0.544304
#  115139/300000: episode: 168, duration: 164.959s, episode steps: 1032, steps per second:   6, episode reward: 15.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.512 [0.000, 5.000],  loss: 0.006691, mean_q: 0.413767, mean_eps: 0.541510
#  115611/300000: episode: 169, duration: 75.475s, episode steps: 472, steps per second:   6, episode reward:  5.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.693 [0.000, 5.000],  loss: 0.006758, mean_q: 0.413959, mean_eps: 0.538502
#  116238/300000: episode: 170, duration: 100.339s, episode steps: 627, steps per second:   6, episode reward:  8.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.510 [0.000, 5.000],  loss: 0.007485, mean_q: 0.419392, mean_eps: 0.536304
#  117050/300000: episode: 171, duration: 129.561s, episode steps: 812, steps per second:   6, episode reward: 16.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.429 [0.000, 5.000],  loss: 0.006734, mean_q: 0.415883, mean_eps: 0.533426
#  117409/300000: episode: 172, duration: 57.575s, episode steps: 359, steps per second:   6, episode reward:  7.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.471 [0.000, 5.000],  loss: 0.006374, mean_q: 0.412256, mean_eps: 0.531084
#  118380/300000: episode: 173, duration: 155.415s, episode steps: 971, steps per second:   6, episode reward: 13.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.433 [0.000, 5.000],  loss: 0.006575, mean_q: 0.415588, mean_eps: 0.528424
#  119230/300000: episode: 174, duration: 135.557s, episode steps: 850, steps per second:   6, episode reward: 17.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.506 [0.000, 5.000],  loss: 0.006284, mean_q: 0.417103, mean_eps: 0.524782
#  119731/300000: episode: 175, duration: 80.070s, episode steps: 501, steps per second:   6, episode reward:  5.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.437 [0.000, 5.000],  loss: 0.005748, mean_q: 0.409379, mean_eps: 0.522080
#  120164/300000: episode: 176, duration: 69.429s, episode steps: 433, steps per second:   6, episode reward:  4.000, mean reward:  0.009 [ 0.000,  1.000], mean action: 2.510 [0.000, 5.000],  loss: 0.008132, mean_q: 0.442202, mean_eps: 0.520212
#  120682/300000: episode: 177, duration: 82.784s, episode steps: 518, steps per second:   6, episode reward:  4.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 2.550 [0.000, 5.000],  loss: 0.011543, mean_q: 0.474656, mean_eps: 0.518310
#  121151/300000: episode: 178, duration: 75.331s, episode steps: 469, steps per second:   6, episode reward:  6.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.646 [0.000, 5.000],  loss: 0.010964, mean_q: 0.468913, mean_eps: 0.516336
#  121601/300000: episode: 179, duration: 72.106s, episode steps: 450, steps per second:   6, episode reward:  9.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.600 [0.000, 5.000],  loss: 0.010346, mean_q: 0.462595, mean_eps: 0.514498
#  121979/300000: episode: 180, duration: 60.484s, episode steps: 378, steps per second:   6, episode reward:  3.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 2.661 [0.000, 5.000],  loss: 0.011107, mean_q: 0.466790, mean_eps: 0.512842
#  122321/300000: episode: 181, duration: 54.825s, episode steps: 342, steps per second:   6, episode reward:  5.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.246 [0.000, 5.000],  loss: 0.010121, mean_q: 0.469143, mean_eps: 0.511402
#  122858/300000: episode: 182, duration: 86.284s, episode steps: 537, steps per second:   6, episode reward:  8.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.471 [0.000, 5.000],  loss: 0.009419, mean_q: 0.471172, mean_eps: 0.509644
#  123444/300000: episode: 183, duration: 93.897s, episode steps: 586, steps per second:   6, episode reward:  9.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.623 [0.000, 5.000],  loss: 0.009658, mean_q: 0.473833, mean_eps: 0.507398
#  124264/300000: episode: 184, duration: 131.100s, episode steps: 820, steps per second:   6, episode reward: 16.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.426 [0.000, 5.000],  loss: 0.009703, mean_q: 0.465159, mean_eps: 0.504586
# Step 125000: saving model to checkpoints/dqn_v06_1_weights_125000.h5f
#  125374/300000: episode: 185, duration: 177.834s, episode steps: 1110, steps per second:   6, episode reward: 19.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.458 [0.000, 5.000],  loss: 0.008834, mean_q: 0.466802, mean_eps: 0.500726
#  125986/300000: episode: 186, duration: 98.128s, episode steps: 612, steps per second:   6, episode reward:  8.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.600 [0.000, 5.000],  loss: 0.010205, mean_q: 0.469373, mean_eps: 0.497282
#  126654/300000: episode: 187, duration: 106.902s, episode steps: 668, steps per second:   6, episode reward: 10.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.873 [0.000, 5.000],  loss: 0.007680, mean_q: 0.464245, mean_eps: 0.494722
#  127026/300000: episode: 188, duration: 59.742s, episode steps: 372, steps per second:   6, episode reward:  7.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.444 [0.000, 5.000],  loss: 0.008060, mean_q: 0.463954, mean_eps: 0.492642
#  127729/300000: episode: 189, duration: 112.656s, episode steps: 703, steps per second:   6, episode reward: 16.000, mean reward:  0.023 [ 0.000,  1.000], mean action: 2.728 [0.000, 5.000],  loss: 0.007617, mean_q: 0.463158, mean_eps: 0.490492
#  128553/300000: episode: 190, duration: 131.956s, episode steps: 824, steps per second:   6, episode reward: 19.000, mean reward:  0.023 [ 0.000,  1.000], mean action: 2.558 [0.000, 5.000],  loss: 0.008173, mean_q: 0.467600, mean_eps: 0.487438
#  128876/300000: episode: 191, duration: 51.845s, episode steps: 323, steps per second:   6, episode reward:  4.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.582 [0.000, 5.000],  loss: 0.007512, mean_q: 0.470172, mean_eps: 0.485144
#  129323/300000: episode: 192, duration: 71.931s, episode steps: 447, steps per second:   6, episode reward:  5.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.349 [0.000, 5.000],  loss: 0.007867, mean_q: 0.457119, mean_eps: 0.483604
#  129728/300000: episode: 193, duration: 65.027s, episode steps: 405, steps per second:   6, episode reward:  8.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.788 [0.000, 5.000],  loss: 0.006546, mean_q: 0.461258, mean_eps: 0.481900
#  130134/300000: episode: 194, duration: 65.441s, episode steps: 406, steps per second:   6, episode reward:  9.000, mean reward:  0.022 [ 0.000,  1.000], mean action: 2.665 [0.000, 5.000],  loss: 0.007987, mean_q: 0.475708, mean_eps: 0.480278
#  130726/300000: episode: 195, duration: 95.145s, episode steps: 592, steps per second:   6, episode reward:  9.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.404 [0.000, 5.000],  loss: 0.010801, mean_q: 0.516020, mean_eps: 0.478282
#  131450/300000: episode: 196, duration: 116.110s, episode steps: 724, steps per second:   6, episode reward: 11.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.591 [0.000, 5.000],  loss: 0.010799, mean_q: 0.505462, mean_eps: 0.475650
#  132118/300000: episode: 197, duration: 107.172s, episode steps: 668, steps per second:   6, episode reward: 12.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.446 [0.000, 5.000],  loss: 0.010459, mean_q: 0.507767, mean_eps: 0.472866
# ...
#  252857/300000: episode: 378, duration: 84.796s, episode steps: 516, steps per second:   6, episode reward:  9.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.364 [0.000, 5.000],  loss: 0.007748, mean_q: 0.872509, mean_eps: 0.200000
#  253448/300000: episode: 379, duration: 97.196s, episode steps: 591, steps per second:   6, episode reward: 11.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.316 [0.000, 5.000],  loss: 0.007278, mean_q: 0.864098, mean_eps: 0.200000
#  253985/300000: episode: 380, duration: 88.318s, episode steps: 537, steps per second:   6, episode reward:  8.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.844 [0.000, 5.000],  loss: 0.007290, mean_q: 0.861362, mean_eps: 0.200000
#  254703/300000: episode: 381, duration: 117.949s, episode steps: 718, steps per second:   6, episode reward: 15.000, mean reward:  0.021 [ 0.000,  1.000], mean action: 2.747 [0.000, 5.000],  loss: 0.006974, mean_q: 0.865357, mean_eps: 0.200000
#  255253/300000: episode: 382, duration: 90.406s, episode steps: 550, steps per second:   6, episode reward:  6.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 3.058 [0.000, 5.000],  loss: 0.006776, mean_q: 0.858753, mean_eps: 0.200000
#  255781/300000: episode: 383, duration: 86.805s, episode steps: 528, steps per second:   6, episode reward: 10.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.140 [0.000, 5.000],  loss: 0.006683, mean_q: 0.854668, mean_eps: 0.200000
#  256790/300000: episode: 384, duration: 165.763s, episode steps: 1009, steps per second:   6, episode reward: 25.000, mean reward:  0.025 [ 0.000,  1.000], mean action: 2.585 [0.000, 5.000],  loss: 0.006667, mean_q: 0.858735, mean_eps: 0.200000
#  257341/300000: episode: 385, duration: 90.745s, episode steps: 551, steps per second:   6, episode reward: 10.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.737 [0.000, 5.000],  loss: 0.006349, mean_q: 0.856882, mean_eps: 0.200000
#  258010/300000: episode: 386, duration: 109.836s, episode steps: 669, steps per second:   6, episode reward: 11.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.371 [0.000, 5.000],  loss: 0.006197, mean_q: 0.863669, mean_eps: 0.200000
#  259010/300000: episode: 387, duration: 164.225s, episode steps: 1000, steps per second:   6, episode reward: 21.000, mean reward:  0.021 [ 0.000,  1.000], mean action: 2.790 [0.000, 5.000],  loss: 0.006002, mean_q: 0.859466, mean_eps: 0.200000
#  259516/300000: episode: 388, duration: 83.041s, episode steps: 506, steps per second:   6, episode reward:  8.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.840 [0.000, 5.000],  loss: 0.006307, mean_q: 0.858700, mean_eps: 0.200000
#  260283/300000: episode: 389, duration: 125.892s, episode steps: 767, steps per second:   6, episode reward: 13.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.562 [0.000, 5.000],  loss: 0.006604, mean_q: 0.868518, mean_eps: 0.200000
#  261068/300000: episode: 390, duration: 128.887s, episode steps: 785, steps per second:   6, episode reward: 14.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.683 [0.000, 5.000],  loss: 0.007896, mean_q: 0.889875, mean_eps: 0.200000
#  261670/300000: episode: 391, duration: 98.740s, episode steps: 602, steps per second:   6, episode reward: 14.000, mean reward:  0.023 [ 0.000,  1.000], mean action: 2.538 [0.000, 5.000],  loss: 0.007725, mean_q: 0.888007, mean_eps: 0.200000
#  262160/300000: episode: 392, duration: 80.495s, episode steps: 490, steps per second:   6, episode reward: 10.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.957 [0.000, 5.000],  loss: 0.007856, mean_q: 0.882639, mean_eps: 0.200000
#  263814/300000: episode: 393, duration: 271.285s, episode steps: 1654, steps per second:   6, episode reward: 29.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.811 [0.000, 5.000],  loss: 0.006870, mean_q: 0.882956, mean_eps: 0.200000
#  264693/300000: episode: 394, duration: 144.141s, episode steps: 879, steps per second:   6, episode reward: 16.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.562 [0.000, 5.000],  loss: 0.006552, mean_q: 0.874398, mean_eps: 0.200000
#  265377/300000: episode: 395, duration: 112.094s, episode steps: 684, steps per second:   6, episode reward: 12.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.792 [0.000, 5.000],  loss: 0.006763, mean_q: 0.876039, mean_eps: 0.200000
#  266088/300000: episode: 396, duration: 116.586s, episode steps: 711, steps per second:   6, episode reward: 13.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.762 [0.000, 5.000],  loss: 0.006644, mean_q: 0.884825, mean_eps: 0.200000
#  266743/300000: episode: 397, duration: 107.647s, episode steps: 655, steps per second:   6, episode reward:  8.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.896 [0.000, 5.000],  loss: 0.006430, mean_q: 0.878893, mean_eps: 0.200000
#  267723/300000: episode: 398, duration: 160.963s, episode steps: 980, steps per second:   6, episode reward: 17.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.523 [0.000, 5.000],  loss: 0.006173, mean_q: 0.875009, mean_eps: 0.200000
#  268419/300000: episode: 399, duration: 114.506s, episode steps: 696, steps per second:   6, episode reward: 13.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.407 [0.000, 5.000],  loss: 0.005986, mean_q: 0.884104, mean_eps: 0.200000
#  269112/300000: episode: 400, duration: 113.876s, episode steps: 693, steps per second:   6, episode reward: 12.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.574 [0.000, 5.000],  loss: 0.005802, mean_q: 0.869895, mean_eps: 0.200000
#  269490/300000: episode: 401, duration: 62.309s, episode steps: 378, steps per second:   6, episode reward:  8.000, mean reward:  0.021 [ 0.000,  1.000], mean action: 2.894 [0.000, 5.000],  loss: 0.005903, mean_q: 0.887050, mean_eps: 0.200000
#  270353/300000: episode: 402, duration: 142.042s, episode steps: 863, steps per second:   6, episode reward: 19.000, mean reward:  0.022 [ 0.000,  1.000], mean action: 2.798 [0.000, 5.000],  loss: 0.006744, mean_q: 0.894299, mean_eps: 0.200000
#  270955/300000: episode: 403, duration: 99.003s, episode steps: 602, steps per second:   6, episode reward:  9.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 3.266 [0.000, 5.000],  loss: 0.008037, mean_q: 0.911003, mean_eps: 0.200000
#  271721/300000: episode: 404, duration: 125.917s, episode steps: 766, steps per second:   6, episode reward: 12.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.916 [0.000, 5.000],  loss: 0.008210, mean_q: 0.904106, mean_eps: 0.200000
#  272344/300000: episode: 405, duration: 102.443s, episode steps: 623, steps per second:   6, episode reward: 11.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.764 [0.000, 5.000],  loss: 0.007190, mean_q: 0.910495, mean_eps: 0.200000
#  273295/300000: episode: 406, duration: 156.065s, episode steps: 951, steps per second:   6, episode reward: 19.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.551 [0.000, 5.000],  loss: 0.007214, mean_q: 0.905172, mean_eps: 0.200000
#  274038/300000: episode: 407, duration: 122.113s, episode steps: 743, steps per second:   6, episode reward: 16.000, mean reward:  0.022 [ 0.000,  1.000], mean action: 2.664 [0.000, 5.000],  loss: 0.006627, mean_q: 0.904168, mean_eps: 0.200000
#  274709/300000: episode: 408, duration: 110.139s, episode steps: 671, steps per second:   6, episode reward: 12.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.434 [0.000, 5.000],  loss: 0.006692, mean_q: 0.892286, mean_eps: 0.200000
# Step 275000: saving model to checkpoints/dqn_v06_1_weights_275000.h5f
#  275337/300000: episode: 409, duration: 103.393s, episode steps: 628, steps per second:   6, episode reward:  8.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.433 [0.000, 5.000],  loss: 0.006406, mean_q: 0.900443, mean_eps: 0.200000
#  276070/300000: episode: 410, duration: 120.522s, episode steps: 733, steps per second:   6, episode reward: 15.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.513 [0.000, 5.000],  loss: 0.006399, mean_q: 0.899193, mean_eps: 0.200000
#  276786/300000: episode: 411, duration: 117.581s, episode steps: 716, steps per second:   6, episode reward: 12.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.648 [0.000, 5.000],  loss: 0.006222, mean_q: 0.908557, mean_eps: 0.200000
#  277319/300000: episode: 412, duration: 87.596s, episode steps: 533, steps per second:   6, episode reward: 14.000, mean reward:  0.026 [ 0.000,  1.000], mean action: 2.313 [0.000, 5.000],  loss: 0.006098, mean_q: 0.907166, mean_eps: 0.200000
#  277995/300000: episode: 413, duration: 110.948s, episode steps: 676, steps per second:   6, episode reward: 13.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.781 [0.000, 5.000],  loss: 0.005751, mean_q: 0.884826, mean_eps: 0.200000
#  279182/300000: episode: 414, duration: 194.988s, episode steps: 1187, steps per second:   6, episode reward: 28.000, mean reward:  0.024 [ 0.000,  1.000], mean action: 2.671 [0.000, 5.000],  loss: 0.005822, mean_q: 0.901139, mean_eps: 0.200000
#  279751/300000: episode: 415, duration: 93.573s, episode steps: 569, steps per second:   6, episode reward:  9.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.666 [0.000, 5.000],  loss: 0.005867, mean_q: 0.886232, mean_eps: 0.200000
#  280362/300000: episode: 416, duration: 100.684s, episode steps: 611, steps per second:   6, episode reward:  9.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.656 [0.000, 5.000],  loss: 0.006697, mean_q: 0.911072, mean_eps: 0.200000
#  281545/300000: episode: 417, duration: 194.397s, episode steps: 1183, steps per second:   6, episode reward: 21.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.607 [0.000, 5.000],  loss: 0.007957, mean_q: 0.918611, mean_eps: 0.200000
#  282324/300000: episode: 418, duration: 128.038s, episode steps: 779, steps per second:   6, episode reward: 15.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.599 [0.000, 5.000],  loss: 0.007794, mean_q: 0.917533, mean_eps: 0.200000
#  283233/300000: episode: 419, duration: 149.296s, episode steps: 909, steps per second:   6, episode reward: 19.000, mean reward:  0.021 [ 0.000,  1.000], mean action: 2.444 [0.000, 5.000],  loss: 0.007221, mean_q: 0.916288, mean_eps: 0.200000
#  283934/300000: episode: 420, duration: 115.396s, episode steps: 701, steps per second:   6, episode reward: 13.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.933 [0.000, 5.000],  loss: 0.007032, mean_q: 0.922210, mean_eps: 0.200000
#  284713/300000: episode: 421, duration: 127.982s, episode steps: 779, steps per second:   6, episode reward: 15.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.639 [0.000, 5.000],  loss: 0.006483, mean_q: 0.919127, mean_eps: 0.200000
#  285433/300000: episode: 422, duration: 118.475s, episode steps: 720, steps per second:   6, episode reward: 12.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.547 [0.000, 5.000],  loss: 0.006220, mean_q: 0.914059, mean_eps: 0.200000
#  286119/300000: episode: 423, duration: 112.643s, episode steps: 686, steps per second:   6, episode reward: 12.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.456 [0.000, 5.000],  loss: 0.006552, mean_q: 0.923733, mean_eps: 0.200000
#  286809/300000: episode: 424, duration: 113.419s, episode steps: 690, steps per second:   6, episode reward: 13.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.358 [0.000, 5.000],  loss: 0.006133, mean_q: 0.915914, mean_eps: 0.200000
#  287526/300000: episode: 425, duration: 117.788s, episode steps: 717, steps per second:   6, episode reward: 17.000, mean reward:  0.024 [ 0.000,  1.000], mean action: 2.646 [0.000, 5.000],  loss: 0.005501, mean_q: 0.910381, mean_eps: 0.200000
#  288300/300000: episode: 426, duration: 127.184s, episode steps: 774, steps per second:   6, episode reward: 16.000, mean reward:  0.021 [ 0.000,  1.000], mean action: 2.619 [0.000, 5.000],  loss: 0.006333, mean_q: 0.915186, mean_eps: 0.200000
#  289068/300000: episode: 427, duration: 126.147s, episode steps: 768, steps per second:   6, episode reward: 17.000, mean reward:  0.022 [ 0.000,  1.000], mean action: 2.370 [0.000, 5.000],  loss: 0.005861, mean_q: 0.915218, mean_eps: 0.200000
#  289932/300000: episode: 428, duration: 142.017s, episode steps: 864, steps per second:   6, episode reward: 17.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.566 [0.000, 5.000],  loss: 0.005509, mean_q: 0.910151, mean_eps: 0.200000
#  291247/300000: episode: 429, duration: 216.007s, episode steps: 1315, steps per second:   6, episode reward: 25.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.654 [0.000, 5.000],  loss: 0.007747, mean_q: 0.937892, mean_eps: 0.200000
#  291930/300000: episode: 430, duration: 112.273s, episode steps: 683, steps per second:   6, episode reward: 13.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.631 [0.000, 5.000],  loss: 0.008034, mean_q: 0.942590, mean_eps: 0.200000
#  292589/300000: episode: 431, duration: 108.334s, episode steps: 659, steps per second:   6, episode reward: 11.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.762 [0.000, 5.000],  loss: 0.007556, mean_q: 0.942559, mean_eps: 0.200000
#  293435/300000: episode: 432, duration: 138.804s, episode steps: 846, steps per second:   6, episode reward: 23.000, mean reward:  0.027 [ 0.000,  1.000], mean action: 2.472 [0.000, 5.000],  loss: 0.007273, mean_q: 0.939995, mean_eps: 0.200000
#  294148/300000: episode: 433, duration: 117.177s, episode steps: 713, steps per second:   6, episode reward: 14.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.449 [0.000, 5.000],  loss: 0.007262, mean_q: 0.936824, mean_eps: 0.200000
#  294745/300000: episode: 434, duration: 97.891s, episode steps: 597, steps per second:   6, episode reward: 11.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.819 [0.000, 5.000],  loss: 0.007009, mean_q: 0.938636, mean_eps: 0.200000
#  295416/300000: episode: 435, duration: 110.018s, episode steps: 671, steps per second:   6, episode reward: 13.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.423 [0.000, 5.000],  loss: 0.006559, mean_q: 0.936655, mean_eps: 0.200000
#  295999/300000: episode: 436, duration: 95.982s, episode steps: 583, steps per second:   6, episode reward: 12.000, mean reward:  0.021 [ 0.000,  1.000], mean action: 2.456 [0.000, 5.000],  loss: 0.006483, mean_q: 0.939822, mean_eps: 0.200000
#  296716/300000: episode: 437, duration: 118.046s, episode steps: 717, steps per second:   6, episode reward: 14.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.513 [0.000, 5.000],  loss: 0.006622, mean_q: 0.947157, mean_eps: 0.200000
#  297350/300000: episode: 438, duration: 104.385s, episode steps: 634, steps per second:   6, episode reward: 10.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.409 [0.000, 5.000],  loss: 0.005912, mean_q: 0.945481, mean_eps: 0.200000
#  297951/300000: episode: 439, duration: 98.754s, episode steps: 601, steps per second:   6, episode reward: 12.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.421 [0.000, 5.000],  loss: 0.005771, mean_q: 0.936280, mean_eps: 0.200000
#  298489/300000: episode: 440, duration: 88.334s, episode steps: 538, steps per second:   6, episode reward:  9.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.669 [0.000, 5.000],  loss: 0.005554, mean_q: 0.938408, mean_eps: 0.200000
#  299490/300000: episode: 441, duration: 164.345s, episode steps: 1001, steps per second:   6, episode reward: 20.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.486 [0.000, 5.000],  loss: 0.005935, mean_q: 0.936218, mean_eps: 0.200000
# Step 300000: saving model to checkpoints/dqn_v06_1_weights_300000.h5f
# done, took 46866.408 seconds
# ⏱ Tiempo de fin: 09:57:39

# %%
# Testing part to calculate the mean reward
#weights_filename = 'dqn_{}_weights.h5f'.format(env_name)
weights_filename = 'dqn_06_1_weights.h5f'.format(env_name)
dqn.load_weights(weights_filename)
dqn.test(env, nb_episodes=10, visualize=False)
# Out:
# Testing for 10 episodes ...
# Episode 1: reward: 19.000, steps: 761
# Episode 2: reward: 18.000, steps: 869
# Episode 3: reward: 17.000, steps: 737
# Episode 4: reward: 21.000, steps: 1192
# Episode 5: reward: 8.000, steps: 506
# Episode 6: reward: 13.000, steps: 855
# Episode 7: reward: 21.000, steps: 879
# Episode 8: reward: 8.000, steps: 434
# Episode 9: reward: 17.000, steps: 800
# Episode 10: reward: 11.000, steps: 492

# %%
from google.colab import drive
import shutil
import glob  # <-- ¡Falta este import!
import os

# 1. Montar Google Drive
#drive.mount('/content/drive')

# 2. Crear directorio en Drive si no existe
os.makedirs('/content/gdrive/MyDrive/Colab_Outputs', exist_ok=True)

# 3. Buscar y copiar todos los archivos coincidentes
archivos = glob.glob('dqn_06_1_weights.h5f.*')  # Encuentra todos los archivos con ese patrón

for archivo in archivos:
    shutil.copy(
        archivo,
        f'/content/gdrive/MyDrive/Colab_Outputs/{os.path.basename(archivo)}'
    )
    print(f"¡Archivo {archivo} copiado a Drive!")

# 4. Buscar y copiar todos los archivos coincidentes
archivos = glob.glob('checkpoints/dqn_v06_1_weights*')  # Encuentra todos los archivos con ese patrón

for archivo in archivos:
    shutil.copy(
        archivo,
        f'/content/gdrive/MyDrive/Colab_Outputs/{os.path.basename(archivo)}'
    )

print("✅ ¡Todos los archivos copiados!")
# Out:
# ¡Archivo dqn_06_1_weights.h5f.data-00000-of-00001 copiado a Drive!
# ¡Archivo dqn_06_1_weights.h5f.index copiado a Drive!
# ✅ ¡Todos los archivos copiados!
